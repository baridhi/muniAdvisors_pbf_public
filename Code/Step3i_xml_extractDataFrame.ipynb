# %%
import os
import re
import pandas as pd
from bs4 import BeautifulSoup

def extract_info_from_xml(xml_content):
    soup = BeautifulSoup(xml_content, 'lxml')
    extracted_data = {}

    def get_text_or_none(tag):
        return tag.get_text(strip=True) if tag else None

    def get_input_or_fakebox_value(key):
        input_tag = soup.find('input', {'name': key}) or soup.find('input', {'id': key})
        if input_tag and input_tag.has_attr('value'):
            return input_tag['value'].strip()
        label = soup.find(string=lambda text: text and key.lower() in text.lower())
        if label:
            parent = label.find_parent(['div', 'td'])
            if parent:
                fakebox = parent.find_next('div', class_='fakeBox')
                if fakebox:
                    return fakebox.get_text(strip=True)
        return None

    def get_label_value(label_text):
        label_tag = soup.find(string=lambda text: text and label_text.lower() in text.lower())
        if label_tag:
            parent = label_tag.find_parent(['div', 'td'])
            if parent:
                sibling = parent.find_next_sibling(['div', 'td'])
                return get_text_or_none(sibling)
        return None

    def extract_yes_no_by_label(label):
        section = soup.find(string=lambda text: text and label.lower() in text.lower())
        if section:
            parent = section.find_parent('div', class_='tableRow')
            if parent:
                yes = parent.find('img', {'alt': 'radio button checked'})
                return 'Yes' if yes else 'No'
        return None



    def extract_checkbox(label):
        span = soup.find('span', string=lambda text: text and label.lower() in text.lower())
        if span:
            checked = span.find_previous_sibling('img', {'src': '/Images/box-checked.jpg'})
            return 'Yes' if checked else 'No'
        return 'No'

    def extract_fallback_regex(label):
        pattern = re.compile(rf'{label}\s*[:\-]?\s*([\w\-\.@]+)', re.IGNORECASE)
        match = pattern.search(xml_content)
        return match.group(1) if match else None

    def extract_date_of_formation(soup):
        for h3 in soup.find_all('h3'):
            if 'date of organization' in h3.get_text(strip=True).lower() or 'date of formation' in h3.get_text(strip=True).lower():
                input_tag = h3.find('input', {'type': 'text'})
                if input_tag and input_tag.has_attr('value'):
                    return input_tag['value'].strip()
        return None

    def extract_state_of_incorporation(soup):
        for h3 in soup.find_all('h3'):
            if 'state of incorporation' in h3.get_text(strip=True).lower() or 'state of formation' in h3.get_text(strip=True).lower():
                input_tag = h3.find('input', {'type': 'text'})
                if input_tag and input_tag.has_attr('value'):
                    return input_tag['value'].strip()
        return None

    def extract_principal_office_zip(soup):
        postal_labels = soup.find_all(string=lambda text: text and 'postal code' in text.lower())
        for label in postal_labels:
            parent_div = label.find_parent('div')
            if parent_div:
                fakebox = parent_div.find_next('div', class_='fakeBox')
                if fakebox:
                    zip_candidate = fakebox.get_text(strip=True)
                    if re.match(r'^\d{5}(-\d{4})?$', zip_candidate):
                        return zip_candidate
        zip_input = soup.find('input', {'id': 'zip'})
        if zip_input and zip_input.has_attr('value'):
            return zip_input['value'].strip()
        return None

    def extract_type_of_organization(soup):
        """
        Extracts the selected type of organization by checking for a checked radio button
        next to known organization types.
        """
        org_types = [
            "Corporation",
            "Partnership",
            "Limited Liability Company",
            "Sole Proprietorship",
            "Limited Liability Partnership",
            "Limited Partnership",
            "Other"
        ]
        for org in org_types:
            # Look for a <div> or <td> that contains the organization type text
            candidates = soup.find_all(string=lambda text: text and org.lower() in text.lower())
            for candidate in candidates:
                parent = candidate.find_parent(['div', 'td'])
                if parent:
                    # Look for a checked radio button in the same row or nearby
                    checked_img = parent.find_next('img', {'src': '/Images/radio-checked.jpg'})
                    if checked_img:
                        return org
        return None

    def extract_website(soup):
        # 1. Try input field with id or name 'websiteAddr'
        input_tag = soup.find('input', {'id': 'websiteAddr'}) or soup.find('input', {'name': 'websiteAddr'})
        if input_tag and input_tag.has_attr('value'):
            website = input_tag['value'].strip()
            if website and website.lower().startswith(('http', 'www')) and 'w3.org' not in website.lower():
                return website

        # 2. Try fakeBox near a label containing 'website address'
        label = soup.find(string=lambda text: text and 'website address' in text.lower())
        if label:
            parent = label.find_parent(['div', 'td'])
            if parent:
                fakebox = parent.find_next('div', class_='fakeBox')
                if fakebox:
                    text = fakebox.get_text(strip=True)
                    if text and text.lower().startswith(('http', 'www')) and 'w3.org' not in text.lower():
                        return text

        # 3. Return None if nothing valid is found
        return None

    def extract_solicitation_activity(soup):
        rows = soup.find_all('div', class_='tableRow')
        for row in rows:
            label = row.find('span', string=lambda text: text and 'engage in solicitation activities' in text.lower())
            if label:
                checked = row.find_all('img', {'src': '/Images/radio-checked.jpg'})
                for img in checked:
                    text = img.find_previous(string=True)
                    if text and 'yes' in text.lower():
                        return 'Yes'
                    elif text and 'no' in text.lower():
                        return 'No'
        return None

    def extract_employee_count_robust(soup, label_text, input_key, xml_content):
        # 1. Try radio button format
        rows = soup.find_all('div', class_='tableRow')
        for row in rows:
            label = row.find(string=lambda text: text and label_text.lower() in text.lower())
            if label:
                checked = row.find('img', {'src': '/Images/radio-checked.jpg'})
                if checked:
                    value = checked.find_previous(string=True)
                    if value:
                        return value.strip()

        # 2. Try input or fakeBox
        input_tag = soup.find('input', {'name': input_key}) or soup.find('input', {'id': input_key})
        if input_tag and input_tag.has_attr('value'):
            return input_tag['value'].strip()

        label = soup.find(string=lambda text: text and input_key.lower() in text.lower())
        if label:
            parent = label.find_parent(['div', 'td'])
            if parent:
                fakebox = parent.find_next('div', class_='fakeBox')
                if fakebox:
                    return fakebox.get_text(strip=True)

        # 3. Fallback regex
        pattern = re.compile(rf'{label_text}\s*[:\-]?\s*([\w\-]+)', re.IGNORECASE)
        match = pattern.search(xml_content)
        if match:
            return match.group(1)

        return None
    

    # --- Extract Fields ---
    extracted_data['Form Name'] = get_text_or_none(soup.find('div', class_='title1'))
    extracted_data['CIK'] = get_input_or_fakebox_value('CIK') or get_input_or_fakebox_value('cik') or get_label_value('CIK') or extract_fallback_regex('CIK')
    extracted_data['Firm Legal Name'] = get_input_or_fakebox_value('legalNm') or get_label_value('Firm Name') or extract_fallback_regex('Firm Name')
    extracted_data['IRS EIN'] = get_input_or_fakebox_value('IRSId') or get_input_or_fakebox_value('irsEin') or extract_fallback_regex('IRS EIN')
    extracted_data['SEC File No. MA-T'] = get_input_or_fakebox_value('maTFileNumber') or get_input_or_fakebox_value('secFileNumMat') or extract_fallback_regex('SEC File No. MA-T')
    extracted_data['Organization CRD No.'] = get_input_or_fakebox_value('CrdNo') or get_input_or_fakebox_value('orgCrdNum') or get_label_value('Organization CRD No.') or extract_fallback_regex('Organization CRD No.')
    extracted_data['Contact Person'] = get_input_or_fakebox_value('contactPersonNm') or get_label_value('Contact Person') or extract_fallback_regex('Contact Person')
    extracted_data['Contact Phone'] = get_input_or_fakebox_value('contactPh') or get_input_or_fakebox_value('mainPh') or extract_fallback_regex('Contact Phone')
    extracted_data['Contact Email'] = get_input_or_fakebox_value('contactEmailAddr') or get_label_value('Contact Email Address') or extract_fallback_regex('Contact Email Address')
    extracted_data['Principal Office Street Address'] = get_input_or_fakebox_value('street1') or get_label_value('Street Address 1') or extract_fallback_regex('Street Address 1')
    extracted_data['Principal Office City'] = get_input_or_fakebox_value('city') or get_label_value('City') or extract_fallback_regex('City')
    extracted_data['Principal Office State'] = get_input_or_fakebox_value('state') or get_label_value('State') or extract_fallback_regex('State')
    extracted_data['Principal Office Zip'] = extract_principal_office_zip(soup) or get_label_value('Zip') or extract_fallback_regex('Zip')
#     extracted_data['Principal Office Website'] = get_input_or_fakebox_value('websiteAddr') or get_label_value('Website') or extract_fallback_regex('Website')
    extracted_data['Principal Office Website'] = extract_website(soup)


    #Type of organization
    '''
    org_types = ['Corporation', 'Partnership', 'Limited Liability Company', 'Sole Proprietorship', 'Other']
    for org in org_types:
        tag = soup.find('td', string=lambda text: text and org in text)
        if tag and tag.find('img', {'src': '/Images/radio-checked.jpg'}):
            extracted_data['Type of Organization'] = org
            break
    '''           
    extracted_data['Type of Organization'] = extract_type_of_organization(soup)


    extracted_data['Date of Formation'] = get_input_or_fakebox_value('dtOfForm') or extract_date_of_formation(soup) or extract_fallback_regex(r'Date of Formation\s*[:\-]?\s*(\d{1,2}[-/]\d{1,2}[-/]\d{2,4})')
    extracted_data['State of Incorporation/Formation'] = get_input_or_fakebox_value('stateOfInc') or get_input_or_fakebox_value('orgJur') or extract_state_of_incorporation(soup) or extract_fallback_regex('State of Incorporation/Formation')

    # --- Compensation ---
    extracted_data['Compensation contingent on transaction closing or based on size'] = extract_yes_no_by_label('compensation')
    extracted_data['Receives compensation based on par amount'] = extract_checkbox('par amount')
    extracted_data['Receives compensation contingent on closing'] = extract_checkbox('contingent on the closing')
    extracted_data['Receives compensation based on size'] = extract_checkbox('based on the size')

    # --- Solicitation ---
#     extracted_data['Engages in solicitation activities'] = extract_yes_no_by_label2('solicitation activities')
    extracted_data['Engages in solicitation activities'] = extract_solicitation_activity(soup)


    # --- Additional Features ---
#     extracted_data['Total Number of Employees'] = get_input_or_fakebox_value('numEmpl') or extract_fallback_regex('Total Number of Employees')
#     extracted_data['Number of Municipal Advisor Employees'] = get_input_or_fakebox_value('numMaEmpl') or extract_fallback_regex('Number of Municipal Advisor Employees')
    extracted_data['Total Number of Employees'] = extract_employee_count_robust(soup, 'Total number of employees', 'numEmpl', xml_content)
    extracted_data['Number of Municipal Advisor Employees'] = extract_employee_count_robust(soup, 'Number of municipal advisor employees', 'numMaEmpl', xml_content)

    extracted_data['Number of Municipal Entity Clients'] = get_input_or_fakebox_value('numMaClients') or extract_fallback_regex('Number of Municipal Entity Clients')
    extracted_data['Number of Obligated Person Clients'] = get_input_or_fakebox_value('numObligatedClients') or extract_fallback_regex('Number of Obligated Person Clients')
    extracted_data['Total Number of Clients'] = get_input_or_fakebox_value('totNumClients') or extract_fallback_regex('Total Number of Clients')

    # --- Business Size ---
    extracted_data['Gross Revenues'] = None
    for option in [
        "Less than $1,000,000",
        "$1,000,000 to $5,000,000",
        "$5,000,001 to $25,000,000",
        "More than $25,000,000"
    ]:
        td = soup.find('td', string=option)
        if td and td.find('img', {'src': '/Images/radio-checked.jpg'}):
            extracted_data['Gross Revenues'] = option
            break

    extracted_data['Fiscal Year End Date'] = get_input_or_fakebox_value('fiscalYrEndDt') or extract_fallback_regex('Fiscal Year End Date')

    # --- Other Business Activities ---
#     extracted_data['Engages in any other business activities'] = extract_yes_no_by_label('Does the municipal advisor engage in any other business activities?')

    # --- Disclosures ---
    for label in [
        "Criminal Action Disclosure",
        "Regulatory Action Disclosure",
        "Civil Judicial Action Disclosure",
        "Customer Complaint/Arbitration/Civil Litigation Disclosure"
    ]:
        heading = soup.find('h1', string=lambda text: text and label.replace(" Disclosure", "") in text)
        form_div = heading.find_next_sibling('div', class_='form1') if heading else None
        extracted_data[label] = 'Yes' if form_div and form_div.get_text(strip=True) else 'No'

    return extracted_data

def process_multiple_ma_files(file_paths):
    all_data = []
    for file_path in file_paths:
        print(f'Processing file:{file_path}')
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                xml_content = f.read()
            data = extract_info_from_xml(xml_content)
        except UnicodeDecodeError:
            with open(file_path, 'r', encoding='iso-8859-1') as f:
                xml_content = f.read()
            data = extract_info_from_xml(xml_content)
        if data:
            data['Source File'] = os.path.basename(file_path)
            all_data.append(data)
            missing_fields = [k for k, v in data.items() if v is None]
            if missing_fields:
                print(f"Missing fields in {file_path}: {missing_fields}")
    return pd.DataFrame(all_data)


# --- Example Usage 
if __name__ == "__main__":
    # Replace with the actual paths to your XML files
    # For demonstration, assume files are in a 'data' directory relative to the script
    # and use the example file name.
    # folder_path = r"C:\Users\barid\Documents\Papers\Muni_adv_PBF\ma_filings\0002020463" #works somewhat
    # folder_path = r"C:\Users\barid\Documents\Papers\Muni_adv_PBF\ma_filings\0001623387" #works somewhat
    # folder_path = r"C:\Users\barid\Documents\Papers\Muni_adv_PBF\ma_filings\0001617993"
    folder_path = r"D:\PhD_Fin\Muni_adv_PBF\Data2"
    target_substring = "FormMA_X01_primary_doc"
    list_of_files = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if target_substring.lower() in file.lower() and file.endswith(".xml"):
                file_path = os.path.join(root, file)
                # print(f"Collecting: {file_path}")
                list_of_files.append(file_path)
        
    # dummy_file_path = "dummy_form_ma.xml"
    dummy_file_path = [r"C:\Users\barid\Documents\Papers\Muni_adv_PBF\ma_filings\0002020463\MA_0002020463_24_000004_xslFormMA_X01_primary_doc.xml"]
    # dummy_file_path = r"C:\Users\barid\Documents\Papers\Muni_adv_PBF\ma_filings\0001623387"
    
    # Example usage:
    # List of XML files
    # xml_files = [
    #     r'C:\Users\\MA_0002020463_24_000004_xslFormMA_X01_primary_doc.xml'
    # ]
    
    df = process_multiple_ma_files(list_of_files)
    
    # combined_dataframe = process_multiple_ma_files(xml_files)
    print("\nCombined DataFrame from multiple files:")
    df
    # print(df.to_string())

    # with open(dummy_file_path, "w", encoding="utf-8") as f:
    #     f.write(dummy_xml_content)

    # List of your XML files
    # In a real-world scenario, you would populate this list dynamically, e.g.,
    # using glob.glob("path/to/your/xml_files/*.xml")
    # xml_files = [
    #     dummy_file_path
    #     # "path/to/your/another_form_ma_file.xml",
    #     # "path/to/your/third_form_ma_file.xml",
    # ]

# %%
df
# Out:
#      Form Name         CIK                          Firm Legal Name  \
# 0      FORM MA  0000009211       ROBERT W. BAIRD & CO. INCORPORATED
# 1      FORM MA  0000009211                ROBERT W. BAIRD & CO. Inc
# 2      FORM MA  0000009211       ROBERT W. BAIRD & CO. INCORPORATED
# 3      FORM MA  0000009211       ROBERT W. BAIRD & CO. INCORPORATED
# 4      FORM MA  0000009211       ROBERT W. BAIRD & CO. INCORPORATED
# ...        ...         ...                                      ...
# 7856   FORM MA  0002041221  First Security Municipal Advisors, Inc.
# 7857   FORM MA  0002041221  First Security Municipal Advisors, Inc.
# 7858   FORM MA  0002041221  First Security Municipal Advisors, Inc.
# 7859   FORM MA  0002053271                     Patriot Advisors LLC
# 7860   FORM MA  0002056790                       Centro Civica, LLC
#
#          IRS EIN SEC File No. MA-T Organization CRD No.  \
# 0     39-6037917      866-00120-00                 8158
# 1     39-6037917      866-00120-00                 8158
# 2     39-6037917      866-00120-00                 8158
# 3     39-6037917      866-00120-00                 8158
# 4     39-6037917      866-00120-00                 8158
# ...          ...               ...                  ...
# 7856  33-1383623              None                 None
# 7857  33-1383623              None                 None
# 7858  33-1383623              None                 None
# 7859  33-3125094              None                 None
# 7860  33-3241335              None                 None
#
#              Contact Person Contact Phone                Contact Email  \
# 0     DeVona WrightCottrell          None  dwrightcottrell@rwbaird.com
# 1     DeVona WrightCottrell          None  dwrightcottrell@rwbaird.com
# 2     DeVona WrightCottrell          None  dwrightcottrell@rwbaird.com
# 3     DeVona WrightCottrell          None  dwrightcottrell@rwbaird.com
# 4     DeVona WrightCottrell          None  dwrightcottrell@rwbaird.com
# ...                     ...           ...                          ...
# 7856    Walter D. Lomax III          None           blomax@crewsfs.com
# 7857    Walter D. Lomax III          None           blomax@crewsfs.com
# 7858    Walter D. Lomax III          None           blomax@crewsfs.com
# 7859     Kevin George Quinn          None  kquinn@patriot-advisors.com
# 7860      Benjamin Davidson          None         ben@centrocivica.com
#
#      Principal Office Street Address  ... Number of Municipal Entity Clients  \
# 0        215 South Washington Square  ...                               None
# 1            124 West Allegan Street  ...                               None
# 2            124 West Allegan Street  ...                               None
# 3            124 West Allegan Street  ...                               None
# 4            124 West Allegan Street  ...                               None
# ...                              ...  ...                                ...
# 7856           625 Farnsworth Avenue  ...                               None
# 7857           625 Farnsworth Avenue  ...                               None
# 7858           625 Farnsworth Avenue  ...                               None
# 7859                            None  ...                               None
# 7860                            None  ...                               None
#
#      Number of Obligated Person Clients Total Number of Clients  \
# 0                                  None                    None
# 1                                  None                    None
# 2                                  None                    None
# 3                                  None                    None
# 4                                  None                    None
# ...                                 ...                     ...
# 7856                               None                    None
# 7857                               None                    None
# 7858                               None                    None
# 7859                               None                    None
# 7860                               None                    None
#
#      Gross Revenues Fiscal Year End Date Criminal Action Disclosure  \
# 0              None                 None                         No
# 1              None                 None                         No
# 2              None                 None                         No
# 3              None                 None                         No
# 4              None                 None                         No
# ...             ...                  ...                        ...
# 7856           None                 None                         No
# 7857           None                 None                         No
# 7858           None                 None                         No
# 7859           None                 None                         No
# 7860           None                 None                         No
#
#      Regulatory Action Disclosure Civil Judicial Action Disclosure  \
# 0                              No                               No
# 1                              No                               No
# 2                              No                               No
# 3                              No                               No
# 4                              No                               No
# ...                           ...                              ...
# 7856                           No                               No
# 7857                           No                               No
# 7858                           No                               No
# 7859                           No                               No
# 7860                           No                               No
#
#      Customer Complaint/Arbitration/Civil Litigation Disclosure  \
# 0                                                    No
# 1                                                    No
# 2                                                    No
# 3                                                    No
# 4                                                    No
# ...                                                 ...
# 7856                                                 No
# 7857                                                 No
# 7858                                                 No
# 7859                                                 No
# 7860                                                 No
#
#                                             Source File
# 0     MA_0000009211_14_000018_xslFormMA_X01_primary_...
# 1     MA_0000009211_15_000011_xslFormMA_X01_primary_...
# 2     MA_0000009211_15_000026_xslFormMA_X01_primary_...
# 3     MA_0000009211_16_000043_xslFormMA_X01_primary_...
# 4     MA_0000009211_16_000048_xslFormMA_X01_primary_...
# ...                                                 ...
# 7856  MA_0002041221_24_000006_xslFormMA_X01_primary_...
# 7857  MA_0002041221_25_000015_xslFormMA_X01_primary_...
# 7858  MA_0002041221_25_000017_xslFormMA_X01_primary_...
# 7859  MA_0002053271_25_000007_xslFormMA_X01_primary_...
# 7860  MA_0002056790_25_000002_xslFormMA_X01_primary_...
#
# [7861 rows x 34 columns]

# %%
df.to_csv(r'C:\Users\barid\Documents\Papers\Muni_adv_PBF\Data\output_step_3i.csv', index=False)

# %%
# reconcile to check the number of files
ctr = 0
for root, dirs, files in os.walk(folder_path):
    for file in files:
        if target_substring.lower() in file.lower() and file.endswith(".xml"):
            file_path = os.path.join(root, file)
            print(f"File path: {file_path}")
            ctr += 1

print(f"total number of MA files: {ctr}")
# Out:
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_14_000018_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_15_000011_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_15_000026_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_16_000043_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_16_000048_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_16_000065_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_16_000069_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_17_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_18_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_19_000010_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_19_000020_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_19_000024_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_20_000009_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_20_000013_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_21_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_21_000019_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_22_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_22_000014_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_22_000021_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_22_000035_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_22_000039_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_23_000019_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_23_000046_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_23_000050_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_24_000014_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000009211\MA_0000009211_25_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000012518\MA_0000012518_14_000032_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000012518\MA_0000012518_15_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000012518\MA_0000012518_15_000012_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000012518\MA_0000012518_16_000021_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000012518\MA_0000012518_16_000038_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000012518\MA_0000012518_17_000011_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000012933\MA_0000012933_14_000014_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000012933\MA_0000012933_19_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000012933\MA_0000012933_20_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000012933\MA_0000012933_21_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000012933\MA_0000012933_22_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000018026\MA_0000018026_23_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000018026\MA_0000018026_23_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000018026\MA_0000018026_25_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000025142\MA_0000025142_15_000009_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000025142\MA_0000025142_18_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000025142\MA_0000025142_18_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000025142\MA_0000025142_19_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000025142\MA_0000025142_20_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000025142\MA_0000025142_21_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000025142\MA_0000025142_22_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000025142\MA_0000025142_23_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000025142\MA_0000025142_23_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000025142\MA_0000025142_23_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_14_000036_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_15_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_15_000023_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_15_000032_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_16_000043_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_16_000050_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_16_000054_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_16_000059_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_17_000021_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_17_000031_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_18_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_18_000017_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_18_000031_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_19_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_19_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_19_000009_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_19_000014_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_19_000020_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_19_000045_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_20_000011_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_20_000021_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_21_000022_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_21_000035_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_22_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_22_000017_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_22_000025_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_22_000030_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_23_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_23_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_23_000030_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_24_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_24_000031_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000027182\MA_0000027182_25_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036528\MA_0000036528_14_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036528\MA_0000036528_16_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036528\MA_0000036528_17_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036528\MA_0000036528_17_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036528\MA_0000036528_17_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036528\MA_0000036528_17_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036528\MA_0000036528_18_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036528\MA_0000036528_20_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036528\MA_0000036528_20_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036528\MA_0000036528_21_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036528\MA_0000036528_21_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036528\MA_0000036528_22_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036528\MA_0000036528_22_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036882\MA_0000036882_15_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036882\MA_0000036882_17_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036882\MA_0000036882_18_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036882\MA_0000036882_19_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036882\MA_0000036882_20_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036882\MA_0000036882_21_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036882\MA_0000036882_22_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036882\MA_0000036882_22_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036882\MA_0000036882_22_000015_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036882\MA_0000036882_22_000016_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036882\MA_0000036882_23_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036882\MA_0000036882_23_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036882\MA_0000036882_23_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036882\MA_0000036882_24_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000036882\MA_0000036882_25_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_14_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_15_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_15_000009_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_16_000026_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_17_000011_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_18_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_18_000012_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_19_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_19_000010_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_20_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_20_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_20_000009_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_20_000020_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_21_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_21_000016_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_21_000018_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_21_000022_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_22_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_22_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_22_000013_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_23_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_23_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_23_000014_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_24_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_24_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_24_000010_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_24_000011_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049303\MA_0000049303_25_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_14_000011_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_14_000085_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_15_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_15_000021_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_15_000023_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_15_000024_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_15_000029_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_15_000034_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_16_000037_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_16_000041_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_16_000045_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_16_000047_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_16_000050_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_16_000052_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_16_000055_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_16_000108_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_16_000125_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_16_000126_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_16_000128_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_16_000137_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_17_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_17_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_17_000011_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_17_000012_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_17_000017_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000049709\MA_0000049709_17_000035_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050825\MA_0000050825_15_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050825\MA_0000050825_17_000022_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050825\MA_0000050825_18_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050825\MA_0000050825_19_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050825\MA_0000050825_20_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050825\MA_0000050825_21_000016_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050825\MA_0000050825_21_000021_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050825\MA_0000050825_22_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050825\MA_0000050825_23_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050825\MA_0000050825_23_000021_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050825\MA_0000050825_23_000026_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050825\MA_0000050825_23_000029_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050825\MA_0000050825_23_000031_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050825\MA_0000050825_24_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050825\MA_0000050825_24_000024_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050825\MA_0000050825_24_000026_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_14_000061_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_16_000022_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_17_000030_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_18_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_18_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_18_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_18_000011_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_18_000012_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_18_000016_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_18_000017_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_18_000020_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_18_000025_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_18_000027_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_18_000034_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_18_000042_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_18_000045_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_20_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_21_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_21_000020_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_22_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_22_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_22_000009_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_22_000011_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_23_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_23_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_23_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_23_000022_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_23_000023_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_23_000024_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_24_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_24_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_24_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_24_000011_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_24_000014_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_24_000015_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_24_000019_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_24_000020_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_24_000021_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_24_000024_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000050916\MA_0000050916_25_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000053834\MA_0000053834_14_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000053834\MA_0000053834_15_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000053834\MA_0000053834_16_000009_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000053834\MA_0000053834_19_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000053834\MA_0000053834_19_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000053834\MA_0000053834_19_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000053834\MA_0000053834_19_000016_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000053834\MA_0000053834_20_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000053834\MA_0000053834_21_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000053834\MA_0000053834_22_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000064242\MA_0000064242_14_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000064242\MA_0000064242_16_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000064242\MA_0000064242_16_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000064242\MA_0000064242_17_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000064242\MA_0000064242_18_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000064242\MA_0000064242_18_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000064242\MA_0000064242_18_000009_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000064242\MA_0000064242_19_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071002\MA_0000071002_14_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071002\MA_0000071002_17_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071002\MA_0000071002_17_000009_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071002\MA_0000071002_18_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071002\MA_0000071002_19_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071002\MA_0000071002_20_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071002\MA_0000071002_21_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071260\MA_0000071260_17_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071260\MA_0000071260_17_000012_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071260\MA_0000071260_17_000013_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071260\MA_0000071260_17_000019_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071260\MA_0000071260_18_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071260\MA_0000071260_18_000013_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071260\MA_0000071260_19_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071260\MA_0000071260_19_000014_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071260\MA_0000071260_20_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071260\MA_0000071260_21_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071260\MA_0000071260_22_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071260\MA_0000071260_23_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071260\MA_0000071260_24_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000071260\MA_0000071260_25_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_14_000009_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_15_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_15_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_15_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_15_000010_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_15_000014_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_15_000018_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_16_000026_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_16_000029_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_17_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_17_000015_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_17_000020_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_18_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_18_000011_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_18_000019_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_19_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_20_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_20_000019_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_21_000015_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_21_000025_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_22_000021_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_22_000025_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_22_000027_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_22_000030_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_23_000018_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_23_000024_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_23_000028_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_24_000010_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_24_000023_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_24_000041_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000073956\MA_0000073956_25_000011_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000081909\MA_0000081909_14_000016_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000081909\MA_0000081909_15_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000081909\MA_0000081909_16_000020_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000081909\MA_0000081909_16_000022_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000081909\MA_0000081909_18_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000081909\MA_0000081909_18_000009_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000081909\MA_0000081909_19_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000081909\MA_0000081909_19_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000081909\MA_0000081909_19_000011_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000081909\MA_0000081909_21_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000081909\MA_0000081909_21_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000081909\MA_0000081909_21_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000081909\MA_0000081909_22_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000081909\MA_0000081909_22_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000081909\MA_0000081909_23_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000081909\MA_0000081909_24_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000081909\MA_0000081909_24_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_14_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_15_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_16_000014_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_16_000015_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_17_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_17_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_18_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_19_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_20_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_21_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_21_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_22_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_23_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_23_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_23_000011_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_24_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_24_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_24_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_24_000009_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_24_000012_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_24_000013_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000084935\MA_0000084935_25_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000090608\MA_0000090608_15_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000090608\MA_0000090608_20_000015_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000090608\MA_0000090608_21_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000090608\MA_0000090608_21_000011_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000090608\MA_0000090608_22_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000090608\MA_0000090608_23_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000090608\MA_0000090608_23_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000090608\MA_0000090608_23_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000090608\MA_0000090608_23_000009_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000090608\MA_0000090608_23_000010_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000090608\MA_0000090608_23_000011_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000090608\MA_0000090608_23_000012_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000090608\MA_0000090608_24_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000090608\MA_0000090608_24_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000090608\MA_0000090608_25_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000090608\MA_0000090608_25_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000091154\MA_0000091154_19_000020_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_17_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_17_000031_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_17_000073_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_17_000098_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_17_000099_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_17_000109_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_17_000135_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_17_000138_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_17_000154_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_17_000157_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_17_000165_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_17_000170_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_18_000009_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_18_000020_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_18_000054_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_18_000082_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_18_000099_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_19_000010_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_19_000018_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_19_000021_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_19_000066_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_20_000031_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_20_000056_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_20_000082_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_21_000018_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_21_000029_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_21_000036_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_21_000085_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_22_000020_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_22_000040_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_22_000084_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_22_000118_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_23_000053_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_23_000067_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_23_000070_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_23_000076_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_24_000029_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_24_000058_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_24_000066_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_24_000070_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_24_000080_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_24_000095_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_24_000108_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000094403\MA_0000094403_25_000043_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_14_000021_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_15_000014_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_15_000074_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_15_000086_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_15_000093_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_16_000107_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_16_000123_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_16_000130_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_16_000136_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_16_000139_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_16_000141_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_16_000169_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_16_000170_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_17_000021_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_17_000031_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_17_000079_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_17_000081_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_18_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_18_000043_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_19_000013_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_20_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_20_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000103623\MA_0000103623_20_000052_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000107136\MA_0000107136_15_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000107136\MA_0000107136_17_000011_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000107136\MA_0000107136_17_000012_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000107136\MA_0000107136_19_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000107136\MA_0000107136_19_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000107136\MA_0000107136_20_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000107136\MA_0000107136_21_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000107136\MA_0000107136_21_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000107136\MA_0000107136_21_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000107136\MA_0000107136_22_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000107136\MA_0000107136_22_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000107136\MA_0000107136_23_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000107136\MA_0000107136_23_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000107136\MA_0000107136_24_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000107136\MA_0000107136_25_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000107238\MA_0000107238_24_000010_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000107238\MA_0000107238_25_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000107238\MA_0000107238_25_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_14_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_15_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_17_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_19_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_19_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_19_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_20_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_20_000011_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_20_000026_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_21_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_22_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_22_000012_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_22_000013_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_22_000015_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_23_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_24_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_24_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_24_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_24_000012_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0000108634\MA_0000108634_24_000013_xslFormMA_X01_primary_doc.xml
# ...
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001841534\MA_0001841534_23_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001841534\MA_0001841534_23_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001843989\MA_0001614082_25_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001843989\MA_0001843989_21_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001843989\MA_0001843989_22_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001843989\MA_0001843989_23_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001843989\MA_0001843989_24_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001843989\MA_0001843989_24_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001846433\MA_0001846433_21_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001846433\MA_0001846433_22_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001846433\MA_0001846433_24_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001846433\MA_0001846433_24_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001846433\MA_0001846433_25_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001849418\MA_0001849418_21_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001852225\MA_0001852225_24_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001855541\MA_0001855541_21_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001855541\MA_0001855541_21_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001855541\MA_0001855541_22_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001855541\MA_0001855541_23_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001855541\MA_0001855541_24_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001855541\MA_0001855541_25_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001861046\MA_0001861046_21_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001861046\MA_0001861046_22_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001861046\MA_0001861046_24_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001861046\MA_0001861046_25_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001865842\MA_0001865842_21_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001865842\MA_0001865842_22_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001865842\MA_0001865842_23_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001865842\MA_0001865842_24_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001865842\MA_0001865842_25_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001869569\MA_0001799581_23_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001869569\MA_0001869569_21_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001869569\MA_0001869569_22_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001869569\MA_0001869569_25_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001878457\MA_0001878457_21_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001878457\MA_0001878457_22_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001878457\MA_0001878457_23_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001878457\MA_0001878457_23_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001878457\MA_0001878457_24_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001878457\MA_0001878457_24_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001878457\MA_0001878457_24_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001878457\MA_0001878457_25_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001879631\MA_0001879631_21_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001879631\MA_0001879631_23_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001879631\MA_0001879631_24_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001879631\MA_0001879631_25_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001880060\MA_0001880060_21_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001881014\MA_0001881014_21_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001881014\MA_0001881014_21_000013_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001881014\MA_0001881014_22_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001881014\MA_0001881014_23_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001881014\MA_0001881014_23_000017_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001881014\MA_0001881014_23_000021_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001881014\MA_0001881014_23_000022_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001881014\MA_0001881014_24_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001881014\MA_0001881014_24_000012_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001881014\MA_0001881014_24_000013_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001881014\MA_0001881014_25_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001911487\MA_0001911487_22_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001911487\MA_0001911487_22_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001911487\MA_0001911487_23_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001911487\MA_0001911487_24_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001911487\MA_0001911487_25_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001917241\MA_0001917241_22_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001917241\MA_0001917241_23_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001917241\MA_0001917241_24_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001917241\MA_0001917241_25_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001943515\MA_0001943515_22_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001943515\MA_0001943515_23_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001943515\MA_0001943515_24_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001943515\MA_0001943515_25_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001947242\MA_0001947242_22_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001947242\MA_0001947242_22_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001947242\MA_0001947242_22_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001947242\MA_0001947242_23_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001947242\MA_0001947242_23_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001947242\MA_0001947242_24_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001947242\MA_0001947242_24_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001947242\MA_0001947242_25_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001949799\MA_0001949799_24_000010_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001949923\MA_0001949923_22_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001949923\MA_0001949923_23_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001949923\MA_0001949923_24_000009_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001952341\MA_0001952341_22_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001952341\MA_0001952341_23_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001952341\MA_0001952341_24_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001952341\MA_0001952341_25_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001955687\MA_0001955687_22_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001955687\MA_0001955687_22_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001955687\MA_0001955687_23_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001955687\MA_0001955687_24_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001955687\MA_0001955687_25_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001956887\MA_0001956887_23_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001956887\MA_0001956887_24_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001956887\MA_0001956887_24_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001963788\MA_0001963788_23_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001963788\MA_0001963788_24_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001964632\MA_0001964632_23_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001964632\MA_0001964632_23_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001964632\MA_0001964632_24_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001964632\MA_0001964632_24_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001964632\MA_0001964632_24_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001973850\MA_0001973850_23_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001977510\MA_0001977510_23_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001981091\MA_0001981091_23_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001981091\MA_0001981091_23_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001981091\MA_0001981091_24_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001981091\MA_0001981091_24_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001981091\MA_0001981091_25_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001981091\MA_0001981091_25_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001984370\MA_0001984370_23_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001986367\MA_0001986367_23_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001986367\MA_0001986367_23_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001986367\MA_0001986367_24_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001986367\MA_0001986367_25_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0001998552\MA_0001998552_23_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002004588\MA_0002004588_24_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002004588\MA_0002004588_24_000008_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002004588\MA_0002004588_25_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002006358\MA_0002006358_24_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002013292\MA_0002013292_24_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002013292\MA_0002013292_24_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002014289\MA_0002014289_24_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002014289\MA_0002014289_24_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002014289\MA_0002014289_25_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002014682\MA_0000950123_24_003033_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002014682\MA_0002014682_24_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002014682\MA_0002014682_24_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002014682\MA_0002014682_25_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002015149\MA_0002015149_24_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002015149\MA_0002015149_25_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002018374\MA_0002018374_24_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002018374\MA_0002018374_25_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002018374\MA_0002018374_25_000003_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002020463\MA_0002020463_24_000004_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002022027\MA_0002022027_24_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002022027\MA_0002022027_24_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002025701\MA_0002025701_24_000005_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002026816\MA_0001042167_24_000050_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002032620\MA_0002032620_24_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002032620\MA_0002032620_24_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002032620\MA_0002032620_24_000009_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002032620\MA_0002032620_25_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002039856\MA_0002039856_24_000001_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002039856\MA_0002039856_25_000002_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002041221\MA_0002041221_24_000006_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002041221\MA_0002041221_25_000015_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002041221\MA_0002041221_25_000017_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002053271\MA_0002053271_25_000007_xslFormMA_X01_primary_doc.xml
# File path: D:\PhD_Fin\Muni_adv_PBF\Data2\0002056790\MA_0002056790_25_000002_xslFormMA_X01_primary_doc.xml
# total number of MA files: 7861
