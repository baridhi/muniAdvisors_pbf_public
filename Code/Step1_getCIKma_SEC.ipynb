# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import io
import zipfile
import re
from datetime import datetime
import time
from urllib.parse import urljoin

# %%
# !pip install xlrd

# %%
# !pip show xlrd
# Out:
# Name: xlrd
# Version: 2.0.1
# Summary: Library for developers to extract data from Microsoft Excel (tm) .xls spreadsheet files
# Home-page: http://www.python-excel.org/
# Author: Chris Withers
# Author-email: chris@withers.org
# License: BSD
# Location: C:\Users\barid\anaconda3\Lib\site-packages
# Requires:
# Required-by:

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\barid\anaconda3\envs\fuzzy_match\python.exe

# %%
! C:\Users\barid\anaconda3\envs\fuzzy_match\python.exe -m pip install xlrd --upgrade
# Out:
# Requirement already satisfied: xlrd in c:\users\barid\anaconda3\envs\fuzzy_match\lib\site-packages (2.0.1)
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: C:\Users\barid\anaconda3\envs\fuzzy_match\python.exe -m pip install --upgrade pip

# %%
try:
    import xlrd
    print("xlrd is successfully imported.")
except ImportError:
    print("xlrd is NOT installed or accessible in the current kernel.")
# Out:
# xlrd is successfully imported.

# %%
def extract_municipal_advisor_data(url, project_nm, ver, email_id, start_year=2015, start_month=5):
    """
    Downloads and extracts municipal advisor data (Name, File Number, CIK, Year, Month)
    from SEC zipped and standalone .xlsx files, handling .xls formats.

    Args:
        url (str): The base URL of the SEC website.
        project_nm (str): The name of your project.
        ver (str): The version of your project.
        email_id (str): Your email address.
        start_year (int): The year from which to start processing files.
        start_month (int): The month from which to start processing files (1-12).

    Returns:
        pandas.DataFrame: A DataFrame containing the extracted data.
    """
    all_data = []
    project_name = project_nm
    version = ver
    email = email_id

    user_agent = f"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36 ({project_name}/{version} {email})"
    headers = {'User-Agent': user_agent}
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raise an exception for bad status codes
    soup = BeautifulSoup(response.content, 'html.parser')

    download_links_relative = [a['href'] for a in soup.find_all('a', href=True) if 'municipal-advisor' in a['href'] and ('.zip' in a['href'] or '.xlsx' in a['href'])]
    download_links = [urljoin(url, link) for link in download_links_relative]
    print("Number of links obtained =", len(download_links))
    # print("Download links collected = ", download_links)

    ctr=0
    for link in download_links:
        ctr=ctr+1
        print(f"Processing iteration for link # {ctr}")
        try:
            file_name = link.split('/')[-1]
            year = None
            month = None

            # Enhanced regex to handle various zip file name formats
            zip_match = re.search(r'ma[-]?(\d{1,2})(\d{1,2})(\d{2})-?.*\.zip', file_name)
            if zip_match:
                month = int(zip_match.group(1))
                day = int(zip_match.group(2))
                year_short = int(zip_match.group(3))
                year = 2000 + year_short if year_short <= 99 else year_short

            xlsx_match = re.search(r'ma.*?(\d{4})-(\d{2}).*\.xlsx', file_name, re.IGNORECASE)
            if not year and xlsx_match:
                year = int(xlsx_match.group(1))
                month = int(xlsx_match.group(2))
            elif not year:
                xlsx_match_short_year_hyphenated = re.search(r'ma.*?(\d{2})-(\d{2})-(\d{2}).*\.xlsx', file_name, re.IGNORECASE)
                if xlsx_match_short_year_hyphenated:
                    month = int(xlsx_match_short_year_hyphenated.group(1))
                    day = int(xlsx_match_short_year_hyphenated.group(2))
                    year_short = int(xlsx_match_short_year_hyphenated.group(3))
                    year = 2000 + year_short if year_short <= 99 else year_short
                else:
                    xlsx_match_short_year_no_hyphen = re.search(r'ma.*?(\d{2})(\d{2})(\d{2}).*\.xlsx', file_name, re.IGNORECASE)
                    if xlsx_match_short_year_no_hyphen:
                        month = int(xlsx_match_short_year_no_hyphen.group(1))
                        day = int(xlsx_match_short_year_no_hyphen.group(2))
                        year_short = int(xlsx_match_short_year_no_hyphen.group(3))
                        year = 2000 + year_short if year_short <= 99 else year_short
                    else:
                        print(f"Warning: Could not consistently extract year and month from {file_name}. Skipping file.")
                        continue

            if year is not None and (year > start_year or (year == start_year and month >= start_month)):
                print(f"Processing: {file_name}, Year: {year}, Month: {month}")
                response = requests.get(link, headers=headers)
                response.raise_for_status()

                if file_name.endswith('.zip'):
                    try:
                        with zipfile.ZipFile(io.BytesIO(response.content)) as zf:
                            data_files = [f for f in zf.namelist() if f.endswith(('.xlsx', '.csv', '.xls'))]
                            if data_files:
                                data_file = data_files[0]
                                print(f"  Found data file: {data_file} in {file_name}")
                                with zf.open(data_file) as data:
                                    df = read_data_file(data, file_name)
                                    if df is not None and len(df.columns) >= 3:
                                        extract_and_append_data(df, year, month, all_data, file_name, data_file)
                                    elif df is not None:
                                        print(f"  Warning: Less than 3 columns found in {data_file} of {file_name}")
                            else:
                                print(f"    Warning: No Excel/CSV/XLS file found in {file_name}")
                    except zipfile.BadZipFile:
                        print(f"Error: Could not open {file_name} as a zip file.")
                    except Exception as e:
                        print(f"An unexpected error occurred while processing zip file {file_name}: {e}")
                elif file_name.endswith('.xlsx'):
                    try:
                        df = pd.read_excel(io.BytesIO(response.content), header=2, engine='openpyxl')
                        print(f"  Successfully read as Excel (xlsx). Columns: {df.columns.tolist()}")
                        if len(df.columns) >= 3:
                            extract_and_append_data(df, year, month, all_data, file_name, file_name) # Use filename as data_file for standalone xlsx
                        else:
                            print(f"  Warning: Less than 3 columns found in {file_name}")
                    except ImportError:
                        print("  Warning: openpyxl not installed. Cannot read xlsx files.")
                    except Exception as e_xlsx:
                        try:
                            df = pd.read_excel(io.BytesIO(response.content), header=2, engine='xlrd')
                            print(f"  Successfully read as Excel (xls). Columns: {df.columns.tolist()}")
                            if len(df.columns) >= 3:
                                extract_and_append_data(df, year, month, all_data, file_name, file_name) # Use filename as data_file for standalone xlsx
                            else:
                                print(f"  Warning: Less than 3 columns found in {file_name}")
                        except ImportError:
                            print("  Warning: xlrd not installed. Cannot read xls files.")
                        except Exception as e_xls:
                            print(f"  Error reading {file_name} as standalone Excel: {e_xlsx}, {e_xls}")
                time.sleep(1)
        except requests.exceptions.RequestException as e:
            print(f"Error downloading {link}: {e}")
        except Exception as e:
            print(f"An unexpected error occurred while processing {link}: {e}")

    final_df = pd.DataFrame(all_data)
    return final_df

# %%
def read_data_file(data, zip_file_name):
    """Tries to read the data file (xlsx, csv, xls) from the zip archive."""
    df = None
    try:
        df = pd.read_excel(data, header=2, engine='openpyxl')
        print(f"    Successfully read as Excel (xlsx).")
    except ImportError:
        print("    Warning: openpyxl not installed. Cannot read xlsx files.")
    except Exception as e_xlsx:
        try:
            data.seek(0)
            df = pd.read_csv(data, skiprows=2)
            print(f"    Successfully read as CSV.")
        except Exception as e_csv:
            try:
                data.seek(0)
                df = pd.read_excel(data, header=2, engine='xlrd')
                print(f"    Successfully read as Excel (xls).")
            except ImportError:
                print("    Warning: xlrd not installed. Cannot read xls files.")
            except Exception as e_xls:
                print(f"    Error reading data file as xls: {e_xls}")
                print(f"    Error reading data file as both Excel and CSV: {e_xlsx}, {e_csv}")
    return df

# %%
def extract_and_append_data(df, year, month, all_data, file_name, data_file_name):
    """Identifies columns and appends data to the all_data list (including 'Company' and 'File No')."""
    cik_col = None
    registrant_name_col = None
    file_number_col = None

    for col in df.columns:
        lower_col = col.strip().lower()
        if 'cik' in lower_col or 'central index key' in lower_col:
            cik_col = col
        if 'registrant name' in lower_col or 'firm name' in lower_col or 'municipal advisor' in lower_col or 'name of municipal advisor' in lower_col or 'company' in lower_col:
            registrant_name_col = col
        if 'file no' in lower_col or 'file number' in lower_col or 'sec file no' in lower_col or 'sec file number' in lower_col:
            file_number_col = col

    if registrant_name_col and file_number_col and cik_col:
        for index, row in df.iterrows():
            name = row.get(registrant_name_col)
            file_no = row.get(file_number_col)
            cik = str(int(float(row.get(cik_col)))) if pd.notna(row.get(cik_col)) else None
            if cik:
                all_data.append({
                    'Registrant Name': name,
                    'File Number': file_no,
                    'CIK': cik.zfill(10),
                    'Year': year,
                    'Month': month
                })
    else:
        print(f"    Warning: Could not identify all required columns in {data_file_name} of {file_name}. Columns found: {df.columns.tolist()}")

# %%
if __name__ == "__main__":
    sec_base_url = "https://www.sec.gov"  # Use the base URL
    relative_path = "/data-research/sec-markets-data/information-about-registered-municipal-advisors"
    full_url = urljoin(sec_base_url, relative_path)
    project_name = "get_cik"  # Replace with your project name
    version = "1.0"  # Replace with your project version
    email = "bmalakar3@gatech.edu"  # Replace with your email address
    # municipal_advisor_df = extract_municipal_advisor_data(full_url, project_name, version, email, start_year=2015, start_month=5)
    municipal_advisor_df = extract_municipal_advisor_data(full_url, project_name, version, email, start_year=2015, start_month=5)
    print("\nCompiled Municipal Advisor CIKs:")
    print(municipal_advisor_df)
    
    # save the DataFrame to a CSV file if needed
    # municipal_advisor_ciks_df.to_csv("municipal_advisor_ciks.csv", index=False)
# Out:
# Number of links obtained = 119
# Processing iteration for link # 1
# Processing: ma040125.xlsx, Year: 2025, Month: 4
#   Successfully read as Excel (xlsx). Columns: ['Registrant Name', 'File Number', 'CIK']
# Processing iteration for link # 2
# Processing: ma030125.xlsx, Year: 2025, Month: 3
#   Successfully read as Excel (xlsx). Columns: ['Registrant Name', 'File Number', 'CIK']
# Processing iteration for link # 3
# Processing: ma020125.xlsx, Year: 2025, Month: 2
#   Successfully read as Excel (xlsx). Columns: ['Registrant Name', 'File Number', 'CIK']
# Processing iteration for link # 4
# Processing: ma010125.xlsx, Year: 2025, Month: 1
#   Successfully read as Excel (xlsx). Columns: ['Registrant Name', 'File Number', 'CIK']
# Processing iteration for link # 5
# Processing: ma120124.xlsx, Year: 2024, Month: 12
#   Successfully read as Excel (xlsx). Columns: ['Registrant Name', 'File Number', 'CIK']
# Processing iteration for link # 6
# Processing: ma110124.xlsx, Year: 2024, Month: 11
#   Successfully read as Excel (xlsx). Columns: ['Registrant Name', 'File Number', 'CIK']
# Processing iteration for link # 7
# Processing: ma100124.xlsx, Year: 2024, Month: 10
#   Successfully read as Excel (xlsx). Columns: ['Registrant Name', 'File Number', 'CIK']
# Processing iteration for link # 8
# Processing: ma090124.xlsx, Year: 2024, Month: 9
#   Successfully read as Excel (xlsx). Columns: ['Registrant Name', 'File Number', 'CIK']
# Processing iteration for link # 9
# Processing: ma080124.xlsx, Year: 2024, Month: 8
#   Successfully read as Excel (xlsx). Columns: ['Registrant Name', 'File Number', 'CIK']
# Processing iteration for link # 10
# Processing: ma070124.xlsx, Year: 2024, Month: 7
#   Successfully read as Excel (xlsx). Columns: ['Registrant Name', 'File Number', 'CIK']
# Processing iteration for link # 11
# Processing: ma060124_1.xlsx, Year: 2024, Month: 6
#   Successfully read as Excel (xlsx). Columns: ['Registrant Name', 'File Number', 'CIK']
# Processing iteration for link # 12
# Processing: ma050124.xlsx, Year: 2024, Month: 5
#   Successfully read as Excel (xlsx). Columns: ['Registrant Name', 'File Number', 'CIK']
# Processing iteration for link # 13
# Processing: ma040124.xlsx, Year: 2024, Month: 4
#   Successfully read as Excel (xlsx). Columns: ['Registrant Name', 'File Number', 'CIK']
# Processing iteration for link # 14
# Processing: ma030124.xlsx, Year: 2024, Month: 3
#   Successfully read as Excel (xlsx). Columns: ['Registrant Name', 'File Number', 'CIK']
# Processing iteration for link # 15
# Processing: ma020124.xlsx, Year: 2024, Month: 2
#   Successfully read as Excel (xlsx). Columns: ['Registrant Name', 'File Number', 'CIK']
# Processing iteration for link # 16
# Processing: ma010124.xlsx, Year: 2024, Month: 1
#   Successfully read as Excel (xlsx). Columns: ['Registrant Name', 'File Number', 'CIK']
# Processing iteration for link # 17
# Processing: ma120123.xlsx, Year: 2023, Month: 12
#   Successfully read as Excel (xlsx). Columns: ['Registrant Name', 'File Number', 'CIK']
# Processing iteration for link # 18
# Processing: ma110123.xlsx, Year: 2023, Month: 11
#   Successfully read as Excel (xlsx). Columns: ['Registrant Name', 'File Number', 'CIK']
# Processing iteration for link # 19
# Processing: ma100123.zip, Year: 2023, Month: 10
#   Found data file: ma100123.xlsx in ma100123.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 20
# Processing: ma090123.zip, Year: 2023, Month: 9
#   Found data file: ma090123.xlsx in ma090123.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 21
# Processing: ma080123.xlsx, Year: 2023, Month: 8
#   Successfully read as Excel (xlsx). Columns: ['Registrant Name', 'File Number', 'CIK']
# Processing iteration for link # 22
# Processing: ma070123.zip, Year: 2023, Month: 7
#   Found data file: ma070123.xlsx in ma070123.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 23
# Processing: ma060123.zip, Year: 2023, Month: 6
#   Found data file: ma060123.xlsx in ma060123.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 24
# Processing: ma050123.zip, Year: 2023, Month: 5
#   Found data file: ma050123.xlsx in ma050123.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 25
# Processing: ma040123.zip, Year: 2023, Month: 4
#   Found data file: ma040123.xlsx in ma040123.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 26
# Processing: ma030123.zip, Year: 2023, Month: 3
#   Found data file: ma 030123.xlsx in ma030123.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 27
# Processing: ma020123.zip, Year: 2023, Month: 2
#   Found data file: ma020123.xlsx in ma020123.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 28
# Processing: ma010123.zip, Year: 2023, Month: 1
#   Found data file: ma010123.xlsx in ma010123.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 29
# Processing: ma120122.zip, Year: 2022, Month: 12
#   Found data file: ma120122.xlsx in ma120122.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 30
# Processing: ma110122.zip, Year: 2022, Month: 11
#   Found data file: ma110122.xlsx in ma110122.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 31
# Processing: ma100122.zip, Year: 2022, Month: 10
#   Found data file: ma100122.xlsx in ma100122.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 32
# Processing: ma090122.zip, Year: 2022, Month: 9
#   Found data file: ma090122.xlsx in ma090122.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 33
# Processing: ma080122.zip, Year: 2022, Month: 8
#   Found data file: ma080122.xlsx in ma080122.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 34
# Processing: ma070122.zip, Year: 2022, Month: 7
#   Found data file: ma070122.xlsx in ma070122.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 35
# Processing: ma060122.zip, Year: 2022, Month: 6
#   Found data file: ma060122.xlsx in ma060122.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 36
# Processing: ma050122.zip, Year: 2022, Month: 5
#   Found data file: ma050122.xlsx in ma050122.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 37
# Processing: ma040122.zip, Year: 2022, Month: 4
#   Found data file: ma040122.xlsx in ma040122.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 38
# Processing: ma030122.zip, Year: 2022, Month: 3
#   Found data file: ma030122.xlsx in ma030122.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 39
# Processing: ma-020122.zip, Year: 2022, Month: 2
#   Found data file: ma 020122.xlsx in ma-020122.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 40
# Processing: ma010122.zip, Year: 2022, Month: 1
#   Found data file: ma010122.xlsx in ma010122.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 41
# Processing: ma120121.zip, Year: 2021, Month: 12
#   Found data file: ma 120121.xlsx in ma120121.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 42
# Processing: ma-110121.zip, Year: 2021, Month: 11
#   Found data file: ma 110121.xlsx in ma-110121.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 43
# Processing: ma100121.zip, Year: 2021, Month: 10
#   Found data file: ma100121.xlsx in ma100121.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 44
# Processing: ma-090121.zip, Year: 2021, Month: 9
#   Found data file: ma 090121.xlsx in ma-090121.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 45
# Processing: ma080121.zip, Year: 2021, Month: 8
#   Found data file: ma080121.xlsx in ma080121.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 46
# Processing: ma-070121.zip, Year: 2021, Month: 7
#   Found data file: ma-070121.xlsx in ma-070121.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 47
# Processing: ma-060121.zip, Year: 2021, Month: 6
#   Found data file: ma 060121.xlsx in ma-060121.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 48
# Processing: ma050121.zip, Year: 2021, Month: 5
#   Found data file: ma 050121.xlsx in ma050121.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 49
# Processing: ma040121.zip, Year: 2021, Month: 4
#   Found data file: ma040121.xlsx in ma040121.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 50
# Processing: ma-030121.zip, Year: 2021, Month: 3
#   Found data file: ma 030121.xlsx in ma-030121.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 51
# Processing: ma020121.zip, Year: 2021, Month: 2
#   Found data file: ma020121.xlsx in ma020121.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 52
# Processing: ma010121.zip, Year: 2021, Month: 1
#   Found data file: ma010121.xlsx in ma010121.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 53
# Processing: ma120120.zip, Year: 2020, Month: 12
#   Found data file: ma120120.xlsx in ma120120.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 54
# Processing: ma110120.zip, Year: 2020, Month: 11
#   Found data file: ma110120.xlsx in ma110120.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 55
# Processing: ma100120.zip, Year: 2020, Month: 10
#   Found data file: ma100120.xlsx in ma100120.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 56
# Processing: ma090120.zip, Year: 2020, Month: 9
#   Found data file: ma090120.xlsx in ma090120.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 57
# Processing: ma080120.zip, Year: 2020, Month: 8
#   Found data file: ma080120.xlsx in ma080120.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 58
# Processing: ma070120.zip, Year: 2020, Month: 7
#   Found data file: ma070120.xlsx in ma070120.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 59
# Processing: ma060120.zip, Year: 2020, Month: 6
#   Found data file: ma060120.xlsx in ma060120.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 60
# Processing: ma050120.zip, Year: 2020, Month: 5
#   Found data file: ma050120.xlsx in ma050120.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 61
# Processing: ma040120_0.zip, Year: 2020, Month: 4
#   Found data file: ma040120.xls in ma040120_0.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 62
# Processing: ma030120.zip, Year: 2020, Month: 3
#   Found data file: ma030120.xls in ma030120.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 63
# Processing: ma020120.zip, Year: 2020, Month: 2
#   Found data file: ma020120.xls in ma020120.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 64
# Processing: ma010120-3.zip, Year: 2020, Month: 1
#   Found data file: ma010120.xlsx in ma010120-3.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 65
# Processing: ma120119.zip, Year: 2019, Month: 12
#   Found data file: ma120119.xlsx in ma120119.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 66
# Processing: ma110119.zip, Year: 2019, Month: 11
#   Found data file: ma110119.xlsx in ma110119.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 67
# Processing: ma100119.zip, Year: 2019, Month: 10
#   Found data file: ma100119.xlsx in ma100119.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 68
# Processing: ma090119.zip, Year: 2019, Month: 9
#   Found data file: ma090119.xlsx in ma090119.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 69
# Processing: ma080119.zip, Year: 2019, Month: 8
#   Found data file: ma080119.xls in ma080119.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 70
# Processing: ma070119.zip, Year: 2019, Month: 7
#   Found data file: ma070119.xlsx in ma070119.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 71
# Processing: ma060119.zip, Year: 2019, Month: 6
#   Found data file: ma060119.xlsx in ma060119.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 72
# Processing: ma050119.zip, Year: 2019, Month: 5
#   Found data file: ma050119.xlsx in ma050119.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 73
# Processing: ma040119.zip, Year: 2019, Month: 4
#   Found data file: ma040119.xlsx in ma040119.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 74
# Processing: ma020119.zip, Year: 2019, Month: 2
#   Found data file: MA Report as of 02-01-2019.xlsx in ma020119.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 75
# Processing: ma010119.zip, Year: 2019, Month: 1
#   Found data file: ma010119.xlsx in ma010119.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 76
# Processing: ma120118.zip, Year: 2018, Month: 12
#   Found data file: MA Data Report as of 12-01-2018.xlsx in ma120118.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 77
# Processing: ma110118-2.zip, Year: 2018, Month: 11
#   Found data file: MA Data Report as of 11-01-2018.xlsx in ma110118-2.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 78
# Processing: ma100118.zip, Year: 2018, Month: 10
#   Found data file: MA Data Report as of 10-01-2018.xlsx in ma100118.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 79
# Processing: ma090118.zip, Year: 2018, Month: 9
#   Found data file: ma090118.xlsx in ma090118.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 80
# Processing: ma080118.zip, Year: 2018, Month: 8
#   Found data file: MA Report as of 08-01-2018.xlsx in ma080118.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 81
# Processing: ma070118.zip, Year: 2018, Month: 7
#   Found data file: MA Report as of 07-01-2018.xlsx in ma070118.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 82
# Processing: ma060118.zip, Year: 2018, Month: 6
#   Found data file: MA Report as of 06-01-2018.xlsx in ma060118.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 83
# Processing: ma050118.zip, Year: 2018, Month: 5
#   Found data file: MA Report as of 5-01-2018.xlsx in ma050118.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 84
# Processing: ma040118.zip, Year: 2018, Month: 4
#   Found data file: MA Report as of 04-01-2018.xlsx in ma040118.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 85
# Processing: ma030118.zip, Year: 2018, Month: 3
#   Found data file: ma030118.xlsx in ma030118.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 86
# Processing: ma020218.zip, Year: 2018, Month: 2
#   Found data file: ma020218.xlsx in ma020218.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 87
# Processing: ma010118.zip, Year: 2018, Month: 1
#   Found data file: ma010118.xlsx in ma010118.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 88
# Processing: ma120117.zip, Year: 2017, Month: 12
#   Found data file: ma120117.xlsx in ma120117.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 89
# Processing: ma11017.zip, Year: 2017, Month: 11
#   Found data file: ma11017.xlsx in ma11017.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 90
# Processing: ma100117.zip, Year: 2017, Month: 10
#   Found data file: ma100117.zip.xlsx in ma100117.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 91
# Processing: ma090117_0.zip, Year: 2017, Month: 9
#   Found data file: ma090117.xlsx in ma090117_0.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 92
# Processing: ma080117.zip, Year: 2017, Month: 8
#   Found data file: ma080117.xlsx in ma080117.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 93
# Processing: ma070117.zip, Year: 2017, Month: 7
#   Found data file: MA Report as of 07-01-2017.xlsx in ma070117.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 94
# Processing: ma060117.zip, Year: 2017, Month: 6
#   Found data file: ma060117.xlsx in ma060117.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 95
# Processing: ma050117.zip, Year: 2017, Month: 5
#   Found data file: ma050117.xlsx in ma050117.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 96
# Processing: ma040117.zip, Year: 2017, Month: 4
#   Found data file: ma040117.xls in ma040117.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 97
# Processing: ma030117.zip, Year: 2017, Month: 3
#   Found data file: MA Report as of 3-01-2017.xls in ma030117.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 98
# Processing: ma020117.zip, Year: 2017, Month: 2
#   Found data file: ma020117.xls in ma020117.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 99
# Processing: ma010117.zip, Year: 2017, Month: 1
#   Found data file: ma010117.xls in ma010117.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 100
# Processing: ma120116.zip, Year: 2016, Month: 12
#   Found data file: MA Report 12-01-2016.xls in ma120116.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 101
# Processing: ma110116.zip, Year: 2016, Month: 11
#   Found data file: ma110116.xlsx in ma110116.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 102
# Processing: ma100116.zip, Year: 2016, Month: 10
#   Found data file: ma100116.xlsx in ma100116.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 103
# Processing: ma090116.zip, Year: 2016, Month: 9
#   Found data file: MA Report as of 09-01-2016.xlsx in ma090116.zip
#     Successfully read as Excel (xlsx).
# Processing iteration for link # 104
# Processing: ma080116.zip, Year: 2016, Month: 8
#   Found data file: MA Report as of 08-01-2016.xls in ma080116.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 105
# Processing: ma070116.zip, Year: 2016, Month: 7
#   Found data file: MA Report as of 07-01-2016.xls in ma070116.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 106
# Processing: ma060116.zip, Year: 2016, Month: 6
#   Found data file: ma060116.xls in ma060116.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 107
# Processing: ma050116.zip, Year: 2016, Month: 5
#   Found data file: MA Report as of 05-01-2016.xls in ma050116.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 108
# Processing: ma040116.zip, Year: 2016, Month: 4
#   Found data file: MA Report as of April 1, 2016.xls in ma040116.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 109
# Processing: ma030116.zip, Year: 2016, Month: 3
#   Found data file: MA Report as of March 1, 2016.xls in ma030116.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 110
# Processing: ma020116.zip, Year: 2016, Month: 2
#   Found data file: ma020116.xls in ma020116.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 111
# Processing: ma010116.zip, Year: 2016, Month: 1
#   Found data file: MA Report as of 01-01-2016.xls in ma010116.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 112
# Processing: ma120115.zip, Year: 2015, Month: 12
#   Found data file: MA Report as of 12-01-2015.xls in ma120115.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 113
# Processing: ma110115.zip, Year: 2015, Month: 11
#   Found data file: MA Report as of 11-01-2015.xls in ma110115.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 114
# Processing: ma100115.zip, Year: 2015, Month: 10
#   Found data file: MA Report as of 10-01-2015.xls in ma100115.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 115
# Processing: ma090115.zip, Year: 2015, Month: 9
#   Found data file: Current MA Report as of 09-01-2015.xls in ma090115.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 116
# Processing: ma080115.zip, Year: 2015, Month: 8
#   Found data file: Current MA Report as of 08-01-2015.xls in ma080115.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 117
# Processing: ma070715.zip, Year: 2015, Month: 7
#   Found data file: Current MA Report as of 07-07-2015.xls in ma070715.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 118
# Processing: ma060115.zip, Year: 2015, Month: 6
#   Found data file: Current MA Report as of 06-01-2015.xls in ma060115.zip
#     Successfully read as Excel (xls).
# Processing iteration for link # 119
# Processing: ma050115.zip, Year: 2015, Month: 5
#   Found data file: Current MA Report as of 05-01-2015.xls in ma050115.zip
#     Successfully read as Excel (xls).
#
# Compiled Municipal Advisor CIKs:
#                                       Registrant Name  \
# 0                                           &PARTNERS
# 1                 30 Three Sixty Public Finance, Inc.
# 2                        A. M. Peche & Associates LLC
# 3            A.BRIDGE REALVEST SECURITIES CORPORATION
# 4                                A&C Galvan Group LLC
# ...                                               ...
# 64836                      YOUNG AMERICA CAPITAL, LLC
# 64837                                  Yuba Group LLC
# 64838                  ZIONS FIRST NATIONAL BANK /MSD
# 64839                      Zions Public Finance, Inc.
# 64840  Zomermaand Financial Advisory Services, L.L.C.
#
#                      File Number         CIK  Year  Month
# 0                      867-01682  0000107136  2025      4
# 1                      867-02350  0001733578  2025      4
# 2                      867-00111  0001613201  2025      4
# 3                      867-01291  0001005399  2025      4
# 4                      867-02679  0002013292  2025      4
# ...                          ...         ...   ...    ...
# 64836  867-01657                  0001463911  2015      5
# 64837  867-00105                  0001612952  2015      5
# 64838  867-00724                  0000797595  2015      5
# 64839  867-01453                  0001628261  2015      5
# 64840  867-00384                  0001589157  2015      5
#
# [64841 rows x 5 columns]

# %%
print(municipal_advisor_df.columns)
# Out:
# Index(['Registrant Name', 'File Number', 'CIK', 'Year', 'Month'], dtype='object')

# %%
municipal_advisor_df.describe()
# Out:
#                Year         Month
# count  64841.000000  64841.000000
# mean    2019.386345      6.553045
# std        2.890556      3.439048
# min     2015.000000      1.000000
# 25%     2017.000000      4.000000
# 50%     2019.000000      7.000000
# 75%     2022.000000     10.000000
# max     2025.000000     12.000000

# %%
municipal_advisor_df['CIK'].nunique()
# Out:
# 920

# %%
# count the number of unique year-month combinations in the df
municipal_advisor_df['yearMth'] = municipal_advisor_df['Year'].astype(str)+ '-' + municipal_advisor_df['Month'].astype(str).str.zfill(2)
yr_mth_count = municipal_advisor_df.groupby('yearMth').size()
n_uniq_yrMth = len(yr_mth_count)

print(f"Num of unique year mth combis ={n_uniq_yrMth}")
print("\nBreakdown of counts per month:")
print(yr_mth_count)
# Out:
# Num of unique year mth combis =119
#
# Breakdown of counts per month:
# yearMth
# 2015-05    633
# 2015-06    638
# 2015-07    647
# 2015-08    653
# 2015-09    661
#           ...
# 2024-12    423
# 2025-01    427
# 2025-02    424
# 2025-03    422
# 2025-04    422
# Length: 119, dtype: int64

# %%
uniq_mths_byYr = municipal_advisor_df.groupby('Year')['Month'].nunique()
uniq_mths_byYr
# Out:
# Year
# 2015     8
# 2016    12
# 2017    12
# 2018    12
# 2019    11
# 2020    12
# 2021    12
# 2022    12
# 2023    12
# 2024    12
# 2025     4
# Name: Month, dtype: int64

# %%
# The above looks okay for now. Note, SEC website does not have March 2019 file, so 11 in 2019 is correct.
# In 2015, we start from May when the Excel files were introduced; so 8 is correct.

# %%
# Extracted the pdf's of 2015 manually

file1 = pd.read_excel(r"C:\Users\barid\Documents\Papers\Muni_adv_PBF\ma_filings\ma031515.xlsx", engine='openpyxl')
file1['Year'] = 2015
file1['Month'] = 3
file1 = file1.rename(columns={'Company Name':'Registrant Name'})
file1
# Out:
#                                     Registrant Name    File No      CIK  Year  \
# 0                                 1410 Partners LLC  867-01318  1620673  2015
# 1                            A. Dashen & Associates  867-00672  1617911  2015
# 2                          A. M. Miller & Co., Inc.  867-00872  1618730  2015
# 3                      A. M. Peche & Associates LLC  867-00111  1613201  2015
# 4          A.BRIDGE REALVEST SECURITIES CORPORATION  867-01291  1005399  2015
# ..                                              ...        ...      ...   ...
# 608                      YOUNG AMERICA CAPITAL, LLC  867-01657  1463911  2015
# 609                                  Yuba Group LLC  867-00105  1612952  2015
# 610                  ZIONS FIRST NATIONAL BANK /MSD  867-00724   797595  2015
# 611                      Zions Public Finance, Inc.  867-01453  1628261  2015
# 612  Zomermaand Financial Advisory Services, L.L.C.  867-00384  1589157  2015
#
#      Month
# 0        3
# 1        3
# 2        3
# 3        3
# 4        3
# ..     ...
# 608      3
# 609      3
# 610      3
# 611      3
# 612      3
#
# [613 rows x 5 columns]

# %%
file2 = pd.read_excel(r"C:\Users\barid\Documents\Papers\Muni_adv_PBF\ma_filings\ma040115.xlsx", engine='openpyxl')
file2['Year'] = 2015
file2['Month'] = 4
file2 = file2.rename(columns={'Company':'Registrant Name'})
file2
# Out:
#                                     Registrant Name    File No      CIK  Year  \
# 0                                 1410 Partners LLC  867-01318  1620673  2015
# 1                            A. Dashen & Associates  867-00672  1617911  2015
# 2                          A. M. Miller & Co., Inc.  867-00872  1618730  2015
# 3                      A. M. Peche & Associates LLC  867-00111  1613201  2015
# 4          A.BRIDGE REALVEST SECURITIES CORPORATION  867-01291  1005399  2015
# ..                                              ...        ...      ...   ...
# 622                      YOUNG AMERICA CAPITAL, LLC  867-01657  1463911  2015
# 623                                  Yuba Group LLC  867-00105  1612952  2015
# 624                  ZIONS FIRST NATIONAL BANK /MSD  867-00724   797595  2015
# 625                      Zions Public Finance, Inc.  867-01453  1628261  2015
# 626  Zomermaand Financial Advisory Services, L.L.C.  867-00384  1589157  2015
#
#      Month
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
# ..     ...
# 622      4
# 623      4
# 624      4
# 625      4
# 626      4
#
# [627 rows x 5 columns]

# %%
muni_adv2 = pd.concat([municipal_advisor_df, file1, file2], ignore_index=True)
muni_adv2
# Out:
#                                       Registrant Name File Number         CIK  \
# 0                                           &PARTNERS   867-01682  0000107136
# 1                 30 Three Sixty Public Finance, Inc.   867-02350  0001733578
# 2                        A. M. Peche & Associates LLC   867-00111  0001613201
# 3            A.BRIDGE REALVEST SECURITIES CORPORATION   867-01291  0001005399
# 4                                A&C Galvan Group LLC   867-02679  0002013292
# ...                                               ...         ...         ...
# 66076                      YOUNG AMERICA CAPITAL, LLC         NaN     1463911
# 66077                                  Yuba Group LLC         NaN     1612952
# 66078                  ZIONS FIRST NATIONAL BANK /MSD         NaN      797595
# 66079                      Zions Public Finance, Inc.         NaN     1628261
# 66080  Zomermaand Financial Advisory Services, L.L.C.         NaN     1589157
#
#        Year  Month  yearMth    File No
# 0      2025      4  2025-04        NaN
# 1      2025      4  2025-04        NaN
# 2      2025      4  2025-04        NaN
# 3      2025      4  2025-04        NaN
# 4      2025      4  2025-04        NaN
# ...     ...    ...      ...        ...
# 66076  2015      4      NaN  867-01657
# 66077  2015      4      NaN  867-00105
# 66078  2015      4      NaN  867-00724
# 66079  2015      4      NaN  867-01453
# 66080  2015      4      NaN  867-00384
#
# [66081 rows x 7 columns]

# %%
uniq_mths_byYr = muni_adv2.groupby('Year')['Month'].nunique()
uniq_mths_byYr
# Out:
# Year
# 2015    10
# 2016    12
# 2017    12
# 2018    12
# 2019    11
# 2020    12
# 2021    12
# 2022    12
# 2023    12
# 2024    12
# 2025     4
# Name: Month, dtype: int64

# %%
# export to csv
muni_adv2.to_csv(r"C:\Users\barid\Documents\Papers\Muni_adv_PBF\ma_filings\sec_cik_ma.csv", index=False)
