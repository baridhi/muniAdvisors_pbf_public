# %%
"""
Requirements:
pip install pandas duckduckgo-search rapidfuzz ollama requests
(duckduckgo-search package is sometimes renamed; use `ddgs` if you prefer.)
"""
import sys
# !{sys.executable} -m pip install duckduckgo_search rapidfuzz ollama requests
# Out:
# Requirement already satisfied: duckduckgo_search in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (8.1.1)
# Requirement already satisfied: rapidfuzz in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (3.11.0)
# Requirement already satisfied: ollama in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.4.7)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: click>=8.1.8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from duckduckgo_search) (8.1.8)
# Requirement already satisfied: primp>=0.15.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from duckduckgo_search) (0.15.0)
# Requirement already satisfied: lxml>=5.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from duckduckgo_search) (5.3.0)
# Requirement already satisfied: httpx<0.29,>=0.27 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ollama) (2.10.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests) (2024.12.14)
# Requirement already satisfied: anyio in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpx<0.29,>=0.27->ollama) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpx<0.29,>=0.27->ollama) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ollama) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (4.12.2)
# Requirement already satisfied: sniffio>=1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from anyio->httpx<0.29,>=0.27->ollama) (1.3.1)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python3.12 -m pip install --upgrade pip

# %%
# !pip show duckduckgo_search
# Out:
# Name: duckduckgo_search
# Version: 8.1.1
# Summary: Search for words, documents, images, news, maps and text translation using the DuckDuckGo.com search engine.
# Home-page: https://github.com/deedy5/duckduckgo_search
# Author: deedy5
# Author-email:
# License: MIT License
# Location: /Users/sukanyadatta/bm_code/muni_adv_pbf/muni_adv_pbf/lib/python3.12/site-packages
# Requires: click, lxml, primp
# Required-by:

# %%
import time, json, unicodedata, re, logging, os
from datetime import datetime
import pandas as pd
import requests
from rapidfuzz import fuzz
from duckduckgo_search import DDGS
from ollama import chat  # ollama python package (local Ollama must be running)

import hashlib
import pickle

# %%
df = pd.read_csv("https://www.dropbox.com/scl/fi/eqc8ss2ko0gr9pzf71opc/compiled_matches_merge_1to19.csv?rlkey=o99i45umhbh6ruppakqoo7sdn&st=rjxf2e4i&dl=1", index_col=False)
df
# Out:
#         identifier   sale_date  sdc_amt                         issuer_sdc  \
# 0          2805558  2003-12-02   19.370    Yorba Linda Public Finance Auth
# 1           173548  2003-10-15    7.165                     Berkeley Co SD
# 2           322361  2011-12-05    3.565   Wilkin (Campbell-Tintah) ISD#852
# 3           295632  2011-11-30  276.800  California Infrstr & Eco Dev Bank
# 4           295633  2011-11-30  276.800  California Infrstr & Eco Dev Bank
# ...            ...         ...      ...                                ...
# 332132     1389906  2008-12-04    0.650              Macedon Town-New York
# 332133     2342444  2007-11-19   38.200   Snohomish Co (Marysville) SD #25
# 332134     2933529  2006-06-16   53.800              Academic Finance Corp
# 332135     2881868  2002-07-16    9.510         Kane Co Forest Preserve Dt
# 332136     2938431  2007-11-05    1.000              Richton Park-Illinois
#
#         months_to_final_maturity  issue_id_l  \
# 0                        357.768      100002
# 1                        100.104       10002
# 2                        241.344     1000249
# 3                        316.212     1000254
# 4                        316.212     1000255
# ...                          ...         ...
# 332132                    12.000      668350
# 332133                   216.060      636272
# 332134                   431.604      589820
# 332135                    27.024       98032
# 332136                     2.832      636285
#
#                                            issuer_mergent  mergent_amt  \
# 0                 YORBA LINDA CALIF LEASE REV CTFS PARTN    19370000.0
# 1                             BERKELEY CNTY S C SCH DIST     7165000.0
# 2              CAMPBELL-TINTAH INDPT SCH DIST NO 852 MINN    3565000.0
# 3         CALIFORNIA INFRASTRUCTURE & ECONOMIC DEV BK REV   69200000.0
# 4         CALIFORNIA INFRASTRUCTURE & ECONOMIC DEV BK REV   69200000.0
# ...                                                   ...          ...
# 332132                           VESTAL N Y CENT SCH DIST     651993.0
# 332133                                     WASHINGTON ST    37855000.0
# 332134                WHITE SETTLEMENT TEX INDPT SCH DIST   53277592.5
# 332135  WILL & KANKAKEE CNTYS ILL CMNTY UNIT SCH DIST ...    9600000.0
# 332136      WONDER LAKE VLG ILL SPL SVC AREA NO 3 SPL TAX    1000000.0
#
#        offering_date  final_maturity_mergent  ... merge_source  \
# 0         2003-12-03              362.733340  ...      merge_1
# 1         2003-10-15              101.500000  ...      merge_1
# 2         2011-12-05              244.700000  ...      merge_1
# 3         2011-11-17              320.600010  ...      merge_1
# 4         2011-11-17              320.600010  ...      merge_1
# ...              ...                     ...  ...          ...
# 332132    2008-12-01               56.799999  ...     merge_19
# 332133    2007-11-15               22.333334  ...     merge_19
# 332134    2006-06-15              355.431271  ...     merge_19
# 332135    2002-07-15              228.154715  ...     merge_19
# 332136    2007-11-08              234.866670  ...     merge_19
#
#                  financial_advisor_sdc    financial_advisor_mergent  \
# 0       Harrell & Company Advisors LLC  HARRELL AND CO ADVISORS LLC
# 1          Ross Sinclaire & Associates                          NaN
# 2                  Ehlers & Associates    EHLERS AND ASSOCIATES INC
# 3             Swap Financial Group LLC                          NaN
# 4             Swap Financial Group LLC                          NaN
# ...                                ...                          ...
# 332132           Bernard P Donegan Inc        BERNARD P DONEGAN INC
# 332133                             NaN                          NaN
# 332134                             NaN     SOUTHWEST SECURITIES INC
# 332135                             NaN                          NaN
# 332136                             NaN                          NaN
#
#        offering_type_sdc offering_type_mergent state maturity_yr  insured  \
# 0         Negotiated-Pub                          CA  362.733340      1.0
# 1            Competitive                          SC  101.500000      0.0
# 2            Competitive                  COMP    MN  244.700000      0.0
# 3         Negotiated-Pub                  NEGO    CA  320.600010      0.0
# 4         Negotiated-Pub                  NEGO    CA  320.600010      0.0
# ...                  ...                   ...   ...         ...      ...
# 332132       Competitive                  COMP    NY   56.799999      0.0
# 332133    Negotiated-Pub           NEGO | PPLC    WA   22.333334      NaN
# 332134    Negotiated-Pub                  NEGO    TX  355.431271      0.0
# 332135       Competitive                          IL  228.154715      1.0
# 332136    Negotiated-Pub                  PPLC    IL  234.866670      0.0
#
#         refunding  issue_description
# 0        1.000000                 RV
# 1        1.000000                 GO
# 2        0.000000                 GO
# 3        1.000000                 RV
# 4        1.000000                 RV
# ...           ...                ...
# 332132   0.000000                 GO
# 332133        NaN                 GO
# 332134   1.000000                 GO
# 332135   0.093229                 GO
# 332136   0.000000                 GO
#
# [332137 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['identifier', 'sale_date', 'sdc_amt', 'issuer_sdc',
#        'months_to_final_maturity', 'issue_id_l', 'issuer_mergent',
#        'mergent_amt', 'offering_date', 'final_maturity_mergent',
#        'match_status', 'merge_source', 'financial_advisor_sdc',
#        'financial_advisor_mergent', 'offering_type_sdc',
#        'offering_type_mergent', 'state', 'maturity_yr', 'insured', 'refunding',
#        'issue_description'],
#       dtype='object')

# %%
df2 = df[['identifier','issue_id_l','sale_date','offering_date','financial_advisor_sdc','financial_advisor_mergent']]
df2
# Out:
#         identifier  issue_id_l   sale_date offering_date  \
# 0          2805558      100002  2003-12-02    2003-12-03
# 1           173548       10002  2003-10-15    2003-10-15
# 2           322361     1000249  2011-12-05    2011-12-05
# 3           295632     1000254  2011-11-30    2011-11-17
# 4           295633     1000255  2011-11-30    2011-11-17
# ...            ...         ...         ...           ...
# 332132     1389906      668350  2008-12-04    2008-12-01
# 332133     2342444      636272  2007-11-19    2007-11-15
# 332134     2933529      589820  2006-06-16    2006-06-15
# 332135     2881868       98032  2002-07-16    2002-07-15
# 332136     2938431      636285  2007-11-05    2007-11-08
#
#                  financial_advisor_sdc    financial_advisor_mergent
# 0       Harrell & Company Advisors LLC  HARRELL AND CO ADVISORS LLC
# 1          Ross Sinclaire & Associates                          NaN
# 2                  Ehlers & Associates    EHLERS AND ASSOCIATES INC
# 3             Swap Financial Group LLC                          NaN
# 4             Swap Financial Group LLC                          NaN
# ...                                ...                          ...
# 332132           Bernard P Donegan Inc        BERNARD P DONEGAN INC
# 332133                             NaN                          NaN
# 332134                             NaN     SOUTHWEST SECURITIES INC
# 332135                             NaN                          NaN
# 332136                             NaN                          NaN
#
# [332137 rows x 6 columns]

# %%
# check Nan
cols_to_check = ['financial_advisor_sdc','financial_advisor_mergent']
nan_counts = df[cols_to_check].isna().sum()
nan_counts
# Out:
# financial_advisor_sdc        119230
# financial_advisor_mergent    139538
# dtype: int64

# %%
# check different MA
col1 = df['financial_advisor_sdc'].astype(str).str.lower()
col2 = df['financial_advisor_mergent'].astype(str).str.lower()

match_count = (col1 == col2).sum()
match_count
# Out:
# 163855

# %%
df_unm1 = df2[(df2['financial_advisor_sdc'].astype(str).str.lower() != df2['financial_advisor_mergent'].astype(str).str.lower())]
df_unm1
# Out:
#         identifier  issue_id_l   sale_date offering_date  \
# 0          2805558      100002  2003-12-02    2003-12-03
# 1           173548       10002  2003-10-15    2003-10-15
# 2           322361     1000249  2011-12-05    2011-12-05
# 3           295632     1000254  2011-11-30    2011-11-17
# 4           295633     1000255  2011-11-30    2011-11-17
# ...            ...         ...         ...           ...
# 332128     2893081      483099  2002-10-31    2002-10-31
# 332129     2626853      594417  2006-05-10    2006-05-15
# 332130     2864136      486444  2001-12-14    2001-12-11
# 332131     2914023       90938  2003-09-22    2003-09-19
# 332134     2933529      589820  2006-06-16    2006-06-15
#
#                  financial_advisor_sdc    financial_advisor_mergent
# 0       Harrell & Company Advisors LLC  HARRELL AND CO ADVISORS LLC
# 1          Ross Sinclaire & Associates                          NaN
# 2                  Ehlers & Associates    EHLERS AND ASSOCIATES INC
# 3             Swap Financial Group LLC                          NaN
# 4             Swap Financial Group LLC                          NaN
# ...                                ...                          ...
# 332128           Munistat Services Inc                          NaN
# 332129       Public Finance Associates                          NaN
# 332130           Bernard P Donegan Inc                          NaN
# 332131                             NaN  LERCH VINCI AND HIGGINS LLP
# 332134                             NaN     SOUTHWEST SECURITIES INC
#
# [168282 rows x 6 columns]

# %%
df_unm2 = df_unm1[(pd.notna(df_unm1['financial_advisor_sdc'])) & (pd.notna(df_unm1['financial_advisor_mergent']))]
df_unm2
# Out:
#         identifier  issue_id_l   sale_date offering_date  \
# 0          2805558      100002  2003-12-02    2003-12-03
# 2           322361     1000249  2011-12-05    2011-12-05
# 8          1374110     1000259  2011-12-02    2011-12-02
# 11          744806     1000266  2011-12-06    2011-12-06
# 12          784421     1000267  2011-12-01    2011-12-01
# ...            ...         ...         ...           ...
# 332106     1944587     1736370  2021-05-25    2021-06-01
# 332110     2984526     1788915  2022-06-14    2022-06-07
# 332119      268787     1218194  2013-07-15    2013-07-16
# 332120     2981122     1775090  2021-12-22    2021-12-20
# 332125      982686     1735369  2021-04-28    2021-05-01
#
#                  financial_advisor_sdc    financial_advisor_mergent
# 0       Harrell & Company Advisors LLC  HARRELL AND CO ADVISORS LLC
# 2                  Ehlers & Associates    EHLERS AND ASSOCIATES INC
# 8                       FirstSouthwest           FIRST SOUTHWEST CO
# 11                 Ehlers & Associates    EHLERS AND ASSOCIATES INC
# 12                      FirstSouthwest           FIRST SOUTHWEST CO
# ...                                ...                          ...
# 332106  Specialized Public Finance Inc  ESTRADA HINOJOSA AND CO INC
# 332110             Ehlers & Associates    ROBERT W BAIRD AND CO INC
# 332119                  FirstSouthwest           FIRST SOUTHWEST CO
# 332120      Government Consultants Inc                MUNIGROUP LLC
# 332125          Masterson Advisors LLC    SAMCO CAPITAL MARKETS INC
#
# [128906 rows x 6 columns]

# %%
df_unm3 = df_unm2.drop_duplicates(subset = ['financial_advisor_sdc','financial_advisor_mergent'])
df_unm3
# Out:
#         identifier  issue_id_l   sale_date offering_date  \
# 0          2805558      100002  2003-12-02    2003-12-03
# 2           322361     1000249  2011-12-05    2011-12-05
# 8          1374110     1000259  2011-12-02    2011-12-02
# 15          209010     1000281  2011-12-01    2011-12-01
# 17         1972312     1000283  2011-11-30    2011-11-30
# ...            ...         ...         ...           ...
# 332097     2583707     1779318  2022-02-02    2022-01-31
# 332106     1944587     1736370  2021-05-25    2021-06-01
# 332110     2984526     1788915  2022-06-14    2022-06-07
# 332120     2981122     1775090  2021-12-22    2021-12-20
# 332125      982686     1735369  2021-04-28    2021-05-01
#
#                  financial_advisor_sdc  \
# 0       Harrell & Company Advisors LLC
# 2                  Ehlers & Associates
# 8                       FirstSouthwest
# 15         Ross Sinclaire & Associates
# 17                         Umbaugh LLP
# ...                                ...
# 332097          Hilltop Securities Inc
# 332106  Specialized Public Finance Inc
# 332110             Ehlers & Associates
# 332120      Government Consultants Inc
# 332125          Masterson Advisors LLC
#
#                                 financial_advisor_mergent
# 0                             HARRELL AND CO ADVISORS LLC
# 2                               EHLERS AND ASSOCIATES INC
# 8                                      FIRST SOUTHWEST CO
# 15                      ROSS SINCLAIRE AND ASSOCIATES LLC
# 17      H J UMBAUGH AND ASSOCIATES CERTIFIED PUBLIC AC...
# ...                                                   ...
# 332097                        HAMLIN CAPITAL ADVISORS LLC
# 332106                        ESTRADA HINOJOSA AND CO INC
# 332110                          ROBERT W BAIRD AND CO INC
# 332120                                      MUNIGROUP LLC
# 332125                          SAMCO CAPITAL MARKETS INC
#
# [4967 rows x 6 columns]

# %%
df_unm4 = df_unm2
df_unm4['sale_yr'] = pd.to_datetime(df_unm4['sale_date']).dt.year
df_unm5 = df_unm4.drop_duplicates(subset=['financial_advisor_sdc','financial_advisor_mergent','sale_yr'])
df_unm5
# Out:
# /var/folders/3s/hndc56bd6k754n21bbk34pwc0000gn/T/ipykernel_884/2417621085.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unm4['sale_yr'] = pd.to_datetime(df_unm4['sale_date']).dt.year
#         identifier  issue_id_l   sale_date offering_date  \
# 0          2805558      100002  2003-12-02    2003-12-03
# 2           322361     1000249  2011-12-05    2011-12-05
# 8          1374110     1000259  2011-12-02    2011-12-02
# 15          209010     1000281  2011-12-01    2011-12-01
# 17         1972312     1000283  2011-11-30    2011-11-30
# ...            ...         ...         ...           ...
# 332098     2881065       63964  2002-07-09    2002-07-12
# 332106     1944587     1736370  2021-05-25    2021-06-01
# 332110     2984526     1788915  2022-06-14    2022-06-07
# 332120     2981122     1775090  2021-12-22    2021-12-20
# 332125      982686     1735369  2021-04-28    2021-05-01
#
#                  financial_advisor_sdc  \
# 0       Harrell & Company Advisors LLC
# 2                  Ehlers & Associates
# 8                       FirstSouthwest
# 15         Ross Sinclaire & Associates
# 17                         Umbaugh LLP
# ...                                ...
# 332098    Capital Markets Advisors LLC
# 332106  Specialized Public Finance Inc
# 332110             Ehlers & Associates
# 332120      Government Consultants Inc
# 332125          Masterson Advisors LLC
#
#                                 financial_advisor_mergent  sale_yr
# 0                             HARRELL AND CO ADVISORS LLC     2003
# 2                               EHLERS AND ASSOCIATES INC     2011
# 8                                      FIRST SOUTHWEST CO     2011
# 15                      ROSS SINCLAIRE AND ASSOCIATES LLC     2011
# 17      H J UMBAUGH AND ASSOCIATES CERTIFIED PUBLIC AC...     2011
# ...                                                   ...      ...
# 332098                      PUBLIC FINANCE ASSOCIATES INC     2002
# 332106                        ESTRADA HINOJOSA AND CO INC     2021
# 332110                          ROBERT W BAIRD AND CO INC     2022
# 332120                                      MUNIGROUP LLC     2021
# 332125                          SAMCO CAPITAL MARKETS INC     2021
#
# [12509 rows x 7 columns]

# %%
logging.basicConfig(level=logging.INFO)

DDG = DDGS()  # simple sync client
# Out:
# /var/folders/3s/hndc56bd6k754n21bbk34pwc0000gn/T/ipykernel_884/3361049473.py:3: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   DDG = DDGS()  # simple sync client

# %%
# Config
INPUT_CSV = "input_names.csv"   # must have columns 'name_a' and 'name_b'
OUTPUT_JSONL = "results_v2.jsonl"
OPENCORP_TOKEN = os.getenv("OPENCORP_TOKEN")  # optional

SUFFIX_TOKENS = {
    "inc","incorporated","corp","corporation","co","company","ltd","limited",
    "llc","llp","plc","gmbh","sa","ag","pte","berhad","nv","spa","sarl","the"
}

DDG_CACHE_FILE = "ddg_cache_v2.pkl"
ddg_cache = {}

# Load cache if exists
if os.path.exists(DDG_CACHE_FILE):
    with open(DDG_CACHE_FILE, "rb") as f:
        ddg_cache = pickle.load(f)

# %%
def normalize_name(n: str) -> str:
    if not isinstance(n, str):
        return ""
    s = unicodedata.normalize("NFKD", n).lower()
    s = re.sub(r'[\u2019\u2018]', "'", s)
    s = re.sub(r'[^0-9a-z&\s]', ' ', s)
    s = s.replace('&', ' and ')
    toks = [t for t in s.split() if t.strip()]
    # strip trailing suffix tokens
    while toks and toks[-1] in SUFFIX_TOKENS:
        toks.pop()
    return " ".join(toks).strip()

def fuzzy_scores(n1: str, n2: str) -> dict:
    return {
        "ratio": fuzz.ratio(n1, n2),
        "token_sort": fuzz.token_sort_ratio(n1, n2),
        "token_set": fuzz.token_set_ratio(n1, n2),
        "partial": fuzz.partial_ratio(n1, n2)
    }

# %%
# def ddg_search(query: str, max_results: int = 5):
#     try:
#         results = DDG.text(query, max_results=max_results)
#         # results is a list of dicts: { 'title', 'href', 'body' }
#         return results or []
#     except Exception as e:
#         logging.exception("DDG search failed for %s: %s", query, e)
#         return []

def ddg_search(query: str, year: int = None, max_results: int = 5):
    # append year window to query text
    if year:
        query += f'after: {year}-01-01 before: {year+1}-01-01'
        
    h = hashlib.sha256(query.encode()).hexdigest()
    if h in ddg_cache:
        return ddg_cache[h]

    try:
        results = DDG.text(query, max_results=max_results) or []
        ddg_cache[h] = results
        # Save cache to disk
        with open(DDG_CACHE_FILE, "wb") as f:
            pickle.dump(ddg_cache, f)
        return results
    except Exception as e:
        logging.exception("DDG search failed for %s: %s", query, e)
        return []

def opencorp_search(name: str, token: str = None, max_results=3):
    if not token:
        return []  # no token: skip or try unauthenticated endpoint (limited)
    try:
        url = "https://api.opencorporates.com/v0.4/companies/search"
        params = {"q": name, "per_page": max_results, "api_token": token}
        r = requests.get(url, params=params, timeout=10)
        j = r.json()
        return j.get("results", {}).get("companies", [])
    except Exception as e:
        logging.exception("OpenCorporates search failed: %s", e)
        return []

# %%
from ollama import embeddings

def semantic_rank(query: str, hits: list, model: str = "nomic-embed-text", top_k: int = 3):
    try:
        # Embed the query
        query_vec = embeddings(model=model, prompt=query)["embedding"]

        def embed_text(text):
            return embeddings(model=model, prompt=text)["embedding"]

        # Score each hit by cosine similarity
        results = []
        for h in hits:
            text = f"{h.get('title', '')} {h.get('body', '')}"
            hit_vec = embed_text(text)
            score = cosine_similarity(query_vec, hit_vec)
            results.append((score, h))

        results.sort(reverse=True, key=lambda x: x[0])
        return [r[1] for r in results[:top_k]]
    except Exception as e:
        logging.warning("Semantic ranking failed: %s", e)
        return hits[:top_k]

def cosine_similarity(vec1, vec2):
    import numpy as np
    v1 = np.array(vec1)
    v2 = np.array(vec2)
    return float(np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)))

# %%
# LLM prompt builder
SYSTEM_PROMPT = """You are an exacting research assistant. Given two firm names, fuzz scores, and top web hits for each,
decide whether they refer to the same legal entity. Be conservative. Output ONLY valid JSON with
{verdict, confidence (0-100), explanation (brief), evidence_urls (list)}. If uncertain, use verdict 'ambiguous'."""

# %%
# def build_user_prompt(original_a, original_b, norm_a, norm_b, scores, hits_a, hits_b, opencorp_a, opencorp_b):
def build_user_prompt(original_a, original_b, norm_a, norm_b, scores, summary_a, summary_b, opencorp_a, opencorp_b):
    def hits_text(hits):
        lines = []
        for i, h in enumerate(hits[:3]):
            title = h.get("title") or ""
            href = h.get("href") or h.get("url") or ""
            body = h.get("body") or ""
            lines.append(f"{i+1}. {title} | {href} | {body[:300]}")
        return "\n".join(lines) if lines else "(no hits)"
    oc_text = ""
    if opencorp_a or opencorp_b:
        oc_text += "OpenCorporates A: " + json.dumps(opencorp_a[:2], default=str) + "\n"
        oc_text += "OpenCorporates B: " + json.dumps(opencorp_b[:2], default=str) + "\n"
    prompt = f"""
Original A: {original_a}
Original B: {original_b}
Normalized A: {norm_a}
Normalized B: {norm_b}
Fuzzy scores: {json.dumps(scores)}

Summary of web search for A:
{summary_a}

Summary of web search for B:
{summary_b}

{oc_text}
Using the above, return JSON as requested.
"""
    return prompt

# %%
def query_ollama(prompt: str, model: str = "mistral"):
    try:
        resp = chat(model=model, messages=[{"role":"system","content":SYSTEM_PROMPT},
                                          {"role":"user","content":prompt}])
        text = resp["message"]["content"]  # Ollama typical shape
        return text
    except Exception as e:
        logging.exception("Ollama query failed: %s", e)
        return ""

def parse_json_safe(text: str):
    # Try to find JSON in the output
    try:
        return json.loads(text)
    except Exception:
        # crude attempt: find first { ... } substring
        m = re.search(r'{.*}', text, flags=re.DOTALL)
        if m:
            try:
                return json.loads(m.group(0))
            except Exception:
                return {"verdict":"ambiguous","confidence":0,"explanation":text[:400],"evidence_urls":[]}
        return {"verdict":"ambiguous","confidence":0,"explanation":text[:400],"evidence_urls":[]}

# %%
def summarize_hits(hits, name, model="mistral"):
    if not hits:
        return "(no useful hits)"

    hit_text = "\n".join(
        [f"{i+1}. {h.get('title','')} | {h.get('href','')} | {h.get('body','')[:300]}"
         for i, h in enumerate(hits[:5])]
    )

    system_prompt = "You are a research assistant. Summarize how these web search results relate to the firm: " + name
    prompt = f"Firm name: {name}\n\nTop web search results:\n{hit_text}\n\nGive a short summary (2-3 sentences) about what these results say about the firm."

    try:
        resp = chat(model=model, messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": prompt}
        ])
        return resp["message"]["content"]
    except Exception as e:
        logging.warning("Failed to summarize DDG hits: %s", e)
        return "(error summarizing hits)"

# %%
def decide_row(a, b, a_yr):
    norm_a = normalize_name(a)
    norm_b = normalize_name(b)
    scores = fuzzy_scores(norm_a, norm_b)
    result = {
        "original_a": a, "original_b": b,
        "norm_a": norm_a, "norm_b": norm_b,
        "scores": scores,
        "timestamp": datetime.utcnow().isoformat()+"Z"
    }

    # Quick decision
    if scores["token_set"] >= 95:
        result.update({"llm_verdict":"same","llm_confidence":98,"llm_explanation":"very high token_set fuzzy match","evidence_urls":[]})
        return result
    # else gather web evidence
    # hits_a = ddg_search(a, max_results=5)
    # hits_b = ddg_search(b, max_results=5)
    oc_a = opencorp_search(a, OPENCORP_TOKEN) if OPENCORP_TOKEN else []
    oc_b = opencorp_search(b, OPENCORP_TOKEN) if OPENCORP_TOKEN else []

    raw_hits_a = ddg_search(a, a_yr, max_results=10)
    raw_hits_b = ddg_search(b, a_yr, max_results=10)
    
    hits_a = semantic_rank(a, raw_hits_a, top_k=3)
    hits_b = semantic_rank(b, raw_hits_b, top_k=3)


    # prompt = build_user_prompt(a, b, norm_a, norm_b, scores, hits_a, hits_b, oc_a, oc_b)
    # prompt = build_user_prompt(a, b, norm_a, norm_b, scores, hits_a, hits_b)
    # Summarize DDG hits before building prompt
    ddg_summary_a = summarize_hits(hits_a, a)
    ddg_summary_b = summarize_hits(hits_b, b)
    
    prompt = build_user_prompt(
        a, b, norm_a, norm_b, scores,
        ddg_summary_a, ddg_summary_b,
        oc_a, oc_b
    )

    llm_text = query_ollama(prompt)
    llm_json = parse_json_safe(llm_text)
    result.update({
        "ddg_a": hits_a, "ddg_b": hits_b,
        # "opencorp_a": oc_a, "opencorp_b": oc_b,
        "llm_raw": llm_text,
        "llm_parsed": llm_json
    })
    return result

# %%
def run_all(input_csv=INPUT_CSV, output_jsonl=OUTPUT_JSONL):
    # df = df_unm2
    df = df_unm5
    out_f = open(output_jsonl, "w", encoding="utf8")
    for i, row in df.iterrows():
        a = row.get("financial_advisor_sdc", "")
        a_yr = row.get('sale_yr',9999)
        b = row.get("financial_advisor_mergent", "")
        logging.info("Processing row %d: %s | %s", i, a, b)
        res = decide_row(a, b, a_yr)
        out_f.write(json.dumps(res, default=str) + "\n")
        out_f.flush()
        # polite pause
        time.sleep(1.0)
    out_f.close()
    # Save final cache state
    with open(DDG_CACHE_FILE, "wb") as f:
        pickle.dump(ddg_cache, f)

# %%
if __name__ == "__main__":
    run_all()
# Out:
# INFO:root:Processing row 0: Harrell & Company Advisors LLC | HARRELL AND CO ADVISORS LLC
# /var/folders/3s/hndc56bd6k754n21bbk34pwc0000gn/T/ipykernel_884/585575254.py:9: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat()+"Z"
# INFO:primp:response: https://www.bing.com/search?q=Harrell+%26+Company+Advisors+LLCafter%3A+2003-01-01+before%3A+2004-01-01 200
# INFO:primp:response: https://www.bing.com/search?q=HARRELL+AND+CO+ADVISORS+LLCafter%3A+2003-01-01+before%3A+2004-01-01 200
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/embeddings "HTTP/1.1 200 OK"

# %%
import json

file_path = '/Users/sukanyadatta/bm_code/muni_adv_pbf/Code/results_v2.jsonl'

max_lines_to_print = 100

with open(file_path, 'r') as f:
    for line_number, line in enumerate(f, 1):
        if line_number > max_lines_to_print:
            print(f'Stopped due to max lines = {max_lines_to_print}')
            break
        else:
            line = line.strip()
            if not line:
                continue  # skip empty lines
            try:
                obj = json.loads(line)
                print(f"Line {line_number}: {obj}")
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON on line {line_number}: {e}")
                # Optionally break or continue to skip corrupted line
                break  # or continue
# Out:
# Line 1: {'original_a': 'Harrell & Company Advisors LLC', 'original_b': 'HARRELL AND CO ADVISORS LLC', 'norm_a': 'harrell and company advisors', 'norm_b': 'harrell and co advisors', 'scores': {'ratio': 90.19607843137256, 'token_sort': 90.19607843137256, 'token_set': 93.02325581395348, 'partial': 78.26086956521739}, 'timestamp': '2025-09-27T05:09:04.457072Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 50,\n      "explanation": "Both firm names have minor differences in casing and format of the second word, but no definitive unique identifying information was found to confirm they are the same legal entity.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': 'Both firm names have minor differences in casing and format of the second word, but no definitive unique identifying information was found to confirm they are the same legal entity.', 'evidence_urls': []}}
# Line 2: {'original_a': 'Ehlers & Associates', 'original_b': 'EHLERS AND ASSOCIATES INC', 'norm_a': 'ehlers and associates', 'norm_b': 'ehlers and associates', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:09:38.614203Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 3: {'original_a': 'FirstSouthwest', 'original_b': 'FIRST SOUTHWEST CO', 'norm_a': 'firstsouthwest', 'norm_b': 'first southwest', 'scores': {'ratio': 96.55172413793103, 'token_sort': 96.55172413793103, 'token_set': 96.55172413793103, 'partial': 92.85714285714286}, 'timestamp': '2025-09-27T05:09:39.621784Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 4: {'original_a': 'Ross Sinclaire & Associates', 'original_b': 'ROSS SINCLAIRE AND ASSOCIATES LLC', 'norm_a': 'ross sinclaire and associates', 'norm_b': 'ross sinclaire and associates', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:09:40.629397Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 5: {'original_a': 'Umbaugh LLP', 'original_b': 'H J UMBAUGH AND ASSOCIATES CERTIFIED PUBLIC ACCOUNTANTS LLP', 'norm_a': 'umbaugh', 'norm_b': 'h j umbaugh and associates certified public accountants', 'scores': {'ratio': 22.580645161290324, 'token_sort': 22.580645161290324, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:09:41.636276Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 6: {'original_a': 'Hutchinson Shockey Erley & Co', 'original_b': 'HUTCHINSON SHOCKEY ERLEY AND CO', 'norm_a': 'hutchinson shockey erley and', 'norm_b': 'hutchinson shockey erley and', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:09:42.643847Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 7: {'original_a': 'Piper Jaffray & Co', 'original_b': 'PIPER JAFFRAY AND CO', 'norm_a': 'piper jaffray and', 'norm_b': 'piper jaffray and', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:09:43.648001Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 8: {'original_a': 'Southwestern Capital Mkts Inc', 'original_b': 'SOUTHWESTERN CAPITAL MARKETS INC', 'norm_a': 'southwestern capital mkts', 'norm_b': 'southwestern capital markets', 'scores': {'ratio': 94.33962264150944, 'token_sort': 94.33962264150944, 'token_set': 94.33962264150944, 'partial': 93.61702127659575}, 'timestamp': '2025-09-27T05:09:44.655519Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 50,\n      "explanation": "Both entities have identical normalized names and very high fuzzy scores, but there are no useful web search hits confirming their identity. Without further information or context, it is not possible to definitively say they refer to the same legal entity.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': 'Both entities have identical normalized names and very high fuzzy scores, but there are no useful web search hits confirming their identity. Without further information or context, it is not possible to definitively say they refer to the same legal entity.', 'evidence_urls': []}}
# Line 9: {'original_a': 'RBC Capital Markets', 'original_b': 'RBC CAPITAL MARKETS LLC', 'norm_a': 'rbc capital markets', 'norm_b': 'rbc capital markets', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:09:53.349754Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 10: {'original_a': 'Cender & Company LLC', 'original_b': 'CENDER AND CO LLC', 'norm_a': 'cender and', 'norm_b': 'cender and', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:09:54.357164Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 11: {'original_a': 'Govt Consultants of Louisiana', 'original_b': 'GOVERNMENT CONSULTANTS OF LOUISIANA INC', 'norm_a': 'govt consultants of louisiana', 'norm_b': 'government consultants of louisiana', 'scores': {'ratio': 90.625, 'token_sort': 90.625, 'token_set': 90.625, 'partial': 94.54545454545455}, 'timestamp': '2025-09-27T05:09:55.362794Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 30,\n      "explanation": "The lack of clear and definitive information about both entities online makes it difficult to confirm they are the same legal entity.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 30, 'explanation': 'The lack of clear and definitive information about both entities online makes it difficult to confirm they are the same legal entity.', 'evidence_urls': []}}
# Line 12: {'original_a': 'Robert W Baird & Co Inc', 'original_b': 'ROBERT W BAIRD CO INC', 'norm_a': 'robert w baird and', 'norm_b': 'robert w baird', 'scores': {'ratio': 87.5, 'token_sort': 87.5, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:10:03.784282Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 13: {'original_a': 'FirstSouthwest', 'original_b': 'FIRST SOUTHWEST CO', 'norm_a': 'firstsouthwest', 'norm_b': 'first southwest', 'scores': {'ratio': 96.55172413793103, 'token_sort': 96.55172413793103, 'token_set': 96.55172413793103, 'partial': 92.85714285714286}, 'timestamp': '2025-09-27T05:10:04.791842Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 14: {'original_a': 'Isom Advisors Inc', 'original_b': 'ISOM ADVISORS', 'norm_a': 'isom advisors', 'norm_b': 'isom advisors', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:10:05.799304Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 15: {'original_a': 'Public Financial Mgmt Inc', 'original_b': 'PUBLIC FINANCIAL MANAGEMENT INC', 'norm_a': 'public financial mgmt', 'norm_b': 'public financial management', 'scores': {'ratio': 87.5, 'token_sort': 87.5, 'token_set': 87.5, 'partial': 92.3076923076923}, 'timestamp': '2025-09-27T05:10:06.806837Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n     "verdict": "ambiguous",\n     "confidence": 50,\n     "explanation": "Names are similar but lack supporting evidence from web searches.",\n     "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': 'Names are similar but lack supporting evidence from web searches.', 'evidence_urls': []}}
# Line 16: {'original_a': 'Estrada Hinojosa & Company Inc', 'original_b': 'ESTRADA HINOJOSA AND CO INC', 'norm_a': 'estrada hinojosa and', 'norm_b': 'estrada hinojosa and', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:10:14.430804Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 17: {'original_a': 'Public Resource Advisory Group', 'original_b': 'PUBLIC RESOURCES ADVISORY GRP', 'norm_a': 'public resource advisory group', 'norm_b': 'public resources advisory grp', 'scores': {'ratio': 94.91525423728814, 'token_sort': 94.91525423728814, 'token_set': 94.91525423728814, 'partial': 96.42857142857143}, 'timestamp': '2025-09-27T05:10:15.438073Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 50,\n      "explanation": "Names are similar but fuzzy scores suggest some differences and no useful web search results were found.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': 'Names are similar but fuzzy scores suggest some differences and no useful web search results were found.', 'evidence_urls': []}}
# Line 18: {'original_a': 'C M de Crinis & Co Inc', 'original_b': 'C M DE CRINIS AND CO INC', 'norm_a': 'c m de crinis and', 'norm_b': 'c m de crinis and', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:10:23.474630Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 19: {'original_a': 'Municipal Solutions Assoc', 'original_b': 'MUNISTAT SERVICES INC', 'norm_a': 'municipal solutions assoc', 'norm_b': 'munistat services', 'scores': {'ratio': 42.85714285714286, 'token_sort': 42.85714285714286, 'token_set': 42.857142857142854, 'partial': 50.0}, 'timestamp': '2025-09-27T05:10:24.480980Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 50,\n      "explanation": "Both firms have similar but not identical names and no useful web search results were found to confirm they are the same legal entity.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': 'Both firms have similar but not identical names and no useful web search results were found to confirm they are the same legal entity.', 'evidence_urls': []}}
# Line 20: {'original_a': 'Ponder & Co', 'original_b': 'PONDER AND CO', 'norm_a': 'ponder and', 'norm_b': 'ponder and', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:10:32.846810Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 21: {'original_a': 'Morgan Keegan & Co Inc', 'original_b': 'MORGAN KEEGAN AND CO INC', 'norm_a': 'morgan keegan and', 'norm_b': 'morgan keegan and', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:10:33.850877Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 22: {'original_a': 'Independent Bond & Invest Cons', 'original_b': 'INDEPENDENT BOND AND INVESTMENT CONSULTANTS LLC', 'norm_a': 'independent bond and invest cons', 'norm_b': 'independent bond and investment consultants', 'scores': {'ratio': 85.33333333333333, 'token_sort': 85.33333333333333, 'token_set': 85.33333333333333, 'partial': 91.52542372881356}, 'timestamp': '2025-09-27T05:10:34.858214Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 50,\n      "explanation": "Both firms have similar names and high fuzzy scores, but there are no definitive online evidence to confirm they are the same legal entity.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': 'Both firms have similar names and high fuzzy scores, but there are no definitive online evidence to confirm they are the same legal entity.', 'evidence_urls': []}}
# Line 23: {'original_a': 'Strategic Solutions Center LLC;Caine Mitter & Associates Inc', 'original_b': 'CAINE MITTER AND ASSOCIATES INC', 'norm_a': 'strategic solutions center llc caine mitter and associates', 'norm_b': 'caine mitter and associates', 'scores': {'ratio': 63.52941176470588, 'token_sort': 63.52941176470588, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:10:43.427055Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 24: {'original_a': 'CSG Advisors Incorporated', 'original_b': 'CSG ADVISORS INC', 'norm_a': 'csg advisors', 'norm_b': 'csg advisors', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:10:44.434389Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 25: {'original_a': 'Northland Securities', 'original_b': 'NORTHLAND SECURITIES INC', 'norm_a': 'northland securities', 'norm_b': 'northland securities', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:10:45.441696Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 26: {'original_a': 'Dale Scott & Company Inc', 'original_b': 'DALE SCOTT AND CO INC', 'norm_a': 'dale scott and', 'norm_b': 'dale scott and', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:10:46.446252Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 27: {'original_a': 'Concord Public Financial Advs', 'original_b': 'CONCORD PUBLIC FINANCIAL ADVISORS INC', 'norm_a': 'concord public financial advs', 'norm_b': 'concord public financial advisors', 'scores': {'ratio': 93.5483870967742, 'token_sort': 93.5483870967742, 'token_set': 93.54838709677419, 'partial': 98.24561403508771}, 'timestamp': '2025-09-27T05:10:47.453676Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 50,\n      "explanation": "Both names have a high fuzzy score (93.5483870967742), but no clear web hits to confirm that they refer to the same legal entity.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': 'Both names have a high fuzzy score (93.5483870967742), but no clear web hits to confirm that they refer to the same legal entity.', 'evidence_urls': []}}
# Line 28: {'original_a': 'Moors & Cabot Group', 'original_b': 'MOORS AND CABOT INC', 'norm_a': 'moors and cabot group', 'norm_b': 'moors and cabot', 'scores': {'ratio': 83.33333333333334, 'token_sort': 83.33333333333334, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:10:56.648682Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 29: {'original_a': 'JJB Hilliard WL Lyons Inc', 'original_b': 'JJB HILLIARD WL LYONS LLC', 'norm_a': 'jjb hilliard wl lyons', 'norm_b': 'jjb hilliard wl lyons', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:10:57.656352Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 30: {'original_a': 'Fieldman Rolapp & Associates', 'original_b': 'FIELDMAN ROLAPP AND ASSOCIATES INC', 'norm_a': 'fieldman rolapp and associates', 'norm_b': 'fieldman rolapp and associates', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:10:58.664343Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 31: {'original_a': 'NW Financial', 'original_b': 'NW FINANCIAL GROUP LLC', 'norm_a': 'nw financial', 'norm_b': 'nw financial group', 'scores': {'ratio': 80.0, 'token_sort': 80.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:10:59.669254Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 32: {'original_a': 'Lamont Financial Services Corp;Omnicap Group LLC', 'original_b': 'OMNICAP GROUP LLC', 'norm_a': 'lamont financial services corp omnicap group', 'norm_b': 'omnicap group', 'scores': {'ratio': 45.614035087719294, 'token_sort': 45.614035087719294, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:11:00.675063Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 33: {'original_a': 'Lamont Financial Services Corp;Omnicap Group LLC', 'original_b': 'OMNICAP GROUP LLC', 'norm_a': 'lamont financial services corp omnicap group', 'norm_b': 'omnicap group', 'scores': {'ratio': 45.614035087719294, 'token_sort': 45.614035087719294, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:11:01.682214Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 34: {'original_a': 'Dougherty & Company LLC', 'original_b': 'DOUGHERTY AND CO LLC', 'norm_a': 'dougherty and', 'norm_b': 'dougherty and', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:11:02.685859Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 35: {'original_a': 'Long-Economic Dev Advisors LLC', 'original_b': 'LONG ECONOMIC DEVELOPMENT ADVISORS LLC', 'norm_a': 'long economic dev advisors', 'norm_b': 'long economic development advisors', 'scores': {'ratio': 86.66666666666667, 'token_sort': 86.66666666666667, 'token_set': 91.66666666666667, 'partial': 79.06976744186046}, 'timestamp': '2025-09-27T05:11:03.693202Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 50,\n      "explanation": "Both firm names are very similar, but lack enough distinct web presence to definitively confirm they refer to the same legal entity.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': 'Both firm names are very similar, but lack enough distinct web presence to definitively confirm they refer to the same legal entity.', 'evidence_urls': []}}
# Line 36: {'original_a': 'Phoenix Advisors LLC', 'original_b': 'MUNICIPAL OFFICIALS', 'norm_a': 'phoenix advisors', 'norm_b': 'municipal officials', 'scores': {'ratio': 28.57142857142857, 'token_sort': 22.857142857142854, 'token_set': 22.85714285714286, 'partial': 34.48275862068966}, 'timestamp': '2025-09-27T05:11:11.875635Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n     "verdict": "ambiguous",\n     "confidence": 0,\n     "explanation": "Insufficient information and no clear matches found in the web searches for either firm.",\n     "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 0, 'explanation': 'Insufficient information and no clear matches found in the web searches for either firm.', 'evidence_urls': []}}
# Line 37: {'original_a': 'Coastal Securities', 'original_b': 'COASTAL SECURITIES INC', 'norm_a': 'coastal securities', 'norm_b': 'coastal securities', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:11:19.662789Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 38: {'original_a': 'George K Baum & Company Inc', 'original_b': 'GEORGE K BAUM AND CO INC', 'norm_a': 'george k baum and', 'norm_b': 'george k baum and', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:11:20.670549Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 39: {'original_a': 'Fiscal Advisors & Marketing', 'original_b': 'FISCAL ADVISORS AND MARKETING INC', 'norm_a': 'fiscal advisors and marketing', 'norm_b': 'fiscal advisors and marketing', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:11:21.677529Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 40: {'original_a': 'Ross Sinclaire & Associates', 'original_b': 'ROBERT W BAIRD CO', 'norm_a': 'ross sinclaire and associates', 'norm_b': 'robert w baird', 'scores': {'ratio': 32.55813953488372, 'token_sort': 32.55813953488372, 'token_set': 32.55813953488372, 'partial': 44.44444444444444}, 'timestamp': '2025-09-27T05:11:22.684804Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 0,\n      "explanation": "Insufficient information and no matching web results found to determine if they refer to the same legal entity.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 0, 'explanation': 'Insufficient information and no matching web results found to determine if they refer to the same legal entity.', 'evidence_urls': []}}
# Line 41: {'original_a': 'Springsted Incorporated', 'original_b': 'SPRINGSTED INC', 'norm_a': 'springsted', 'norm_b': 'springsted', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:11:30.598603Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 42: {'original_a': 'Public Financial Mgmt Inc', 'original_b': 'PUBLIC FINANCIAL MANAGEMENT INC', 'norm_a': 'public financial mgmt', 'norm_b': 'public financial management', 'scores': {'ratio': 87.5, 'token_sort': 87.5, 'token_set': 87.5, 'partial': 92.3076923076923}, 'timestamp': '2025-09-27T05:11:31.604041Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n     "verdict": "ambiguous",\n     "confidence": 50,\n     "explanation": "The firms\' names are similar but have minor differences in capitalization and spacing. The lack of informative web hits makes it difficult to confirm if they refer to the same legal entity.",\n     "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': "The firms' names are similar but have minor differences in capitalization and spacing. The lack of informative web hits makes it difficult to confirm if they refer to the same legal entity.", 'evidence_urls': []}}
# Line 43: {'original_a': 'William Blair & Company LLC', 'original_b': 'WILLIAM BLAIR AND CO LLC', 'norm_a': 'william blair and', 'norm_b': 'william blair and', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:11:40.406439Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 44: {'original_a': 'Govt Development Bank for PR', 'original_b': 'GOVERNMENT DEVELOPMENT BANK', 'norm_a': 'govt development bank for pr', 'norm_b': 'government development bank', 'scores': {'ratio': 76.36363636363637, 'token_sort': 76.36363636363637, 'token_set': 76.36363636363636, 'partial': 87.5}, 'timestamp': '2025-09-27T05:11:41.408484Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 50,\n      "explanation": "Both firms\' names are similar but lack sufficient contextual evidence to confirm they refer to the same legal entity.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': "Both firms' names are similar but lack sufficient contextual evidence to confirm they refer to the same legal entity.", 'evidence_urls': []}}
# Line 45: {'original_a': 'BD Advisors', 'original_b': 'BD ADVISORS LLC DENVER COLORADO', 'norm_a': 'bd advisors', 'norm_b': 'bd advisors llc denver colorado', 'scores': {'ratio': 52.38095238095239, 'token_sort': 52.38095238095239, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:11:49.555065Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 46: {'original_a': 'Umbaugh LLP', 'original_b': 'H J UMBAUGH AND ASSOCIATES CERTIFIED PUBLIC ACCOUNTANTS LLP', 'norm_a': 'umbaugh', 'norm_b': 'h j umbaugh and associates certified public accountants', 'scores': {'ratio': 22.580645161290324, 'token_sort': 22.580645161290324, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:11:50.557185Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 47: {'original_a': 'Public Resource Advisory Group;A C Advisory Inc', 'original_b': 'PUBLIC RESOURCES ADVISORY GRP', 'norm_a': 'public resource advisory group a c advisory', 'norm_b': 'public resources advisory grp', 'scores': {'ratio': 77.77777777777779, 'token_sort': 77.77777777777779, 'token_set': 88.88888888888889, 'partial': 96.42857142857143}, 'timestamp': '2025-09-27T05:11:51.561241Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 30,\n      "explanation": "Both names are very similar but lack unique identifying information in web search results.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 30, 'explanation': 'Both names are very similar but lack unique identifying information in web search results.', 'evidence_urls': []}}
# Line 48: {'original_a': 'Estrada Hinojosa & Company Inc;FirstSouthwest', 'original_b': 'FIRST SOUTHWEST CO', 'norm_a': 'estrada hinojosa and company inc firstsouthwest', 'norm_b': 'first southwest', 'scores': {'ratio': 45.16129032258065, 'token_sort': 45.16129032258065, 'token_set': 45.16129032258065, 'partial': 96.55172413793103}, 'timestamp': '2025-09-27T05:11:59.497838Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n     "verdict": "ambiguous",\n     "confidence": 50,\n     "explanation": "Insufficient information and lack of consistent matching between the firm names.",\n     "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': 'Insufficient information and lack of consistent matching between the firm names.', 'evidence_urls': []}}
# Line 49: {'original_a': 'John S Vincent & Company LLC', 'original_b': 'JOHN S VINCENT AND CO LLC', 'norm_a': 'john s vincent and', 'norm_b': 'john s vincent and', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:12:07.266215Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 50: {'original_a': 'Public Financial Mgmt Inc;Acacia Financial Group Inc', 'original_b': 'PUBLIC FINANCIAL MANAGEMENT INC', 'norm_a': 'public financial mgmt inc acacia financial group', 'norm_b': 'public financial management', 'scores': {'ratio': 58.666666666666664, 'token_sort': 61.33333333333333, 'token_set': 74.4186046511628, 'partial': 87.5}, 'timestamp': '2025-09-27T05:12:08.273667Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 50,\n      "explanation": "No clear match found in web searches and fuzzy scores are not conclusive.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': 'No clear match found in web searches and fuzzy scores are not conclusive.', 'evidence_urls': []}}
# Line 51: {'original_a': 'Seattle-Northwest Sec Corp', 'original_b': 'SEATTLE NORTHWEST SECURITIES CORP', 'norm_a': 'seattle northwest sec', 'norm_b': 'seattle northwest securities', 'scores': {'ratio': 85.71428571428572, 'token_sort': 85.71428571428572, 'token_set': 89.47368421052632, 'partial': 100.0}, 'timestamp': '2025-09-27T05:12:14.771551Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n    "verdict": "ambiguous",\n    "confidence": 50,\n    "explanation": "Both names are very similar, but there were no useful web hits to confirm that they refer to the same legal entity.",\n    "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': 'Both names are very similar, but there were no useful web hits to confirm that they refer to the same legal entity.', 'evidence_urls': []}}
# Line 52: {'original_a': 'BB&T Capital Markets', 'original_b': 'BB AND T CAPITAL MARKETS', 'norm_a': 'bb and t capital markets', 'norm_b': 'bb and t capital markets', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:12:23.009097Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 53: {'original_a': 'Public Resource Advisory Group;A C Advisory Inc', 'original_b': 'PUBLIC RESOURCES ADVISORY GRP', 'norm_a': 'public resource advisory group a c advisory', 'norm_b': 'public resources advisory grp', 'scores': {'ratio': 77.77777777777779, 'token_sort': 77.77777777777779, 'token_set': 88.88888888888889, 'partial': 96.42857142857143}, 'timestamp': '2025-09-27T05:12:24.016397Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 30,\n      "explanation": "The fuzzy score suggests a high similarity between the names, but neither name has any useful web hits that can confirm whether they refer to the same legal entity. Therefore, further research is needed.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 30, 'explanation': 'The fuzzy score suggests a high similarity between the names, but neither name has any useful web hits that can confirm whether they refer to the same legal entity. Therefore, further research is needed.', 'evidence_urls': []}}
# Line 54: {'original_a': 'Piper Jaffray & Co', 'original_b': 'PUBLIC FINANCIAL MANAGEMENT INC', 'norm_a': 'piper jaffray and', 'norm_b': 'public financial management', 'scores': {'ratio': 36.36363636363637, 'token_sort': 36.36363636363637, 'token_set': 36.36363636363637, 'partial': 41.379310344827594}, 'timestamp': '2025-09-27T05:12:31.701642Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 0,\n      "explanation": "Both firms have no clear matches in web search and their normalized names have a low fuzzy score (36.36%), indicating a lack of similarity.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 0, 'explanation': 'Both firms have no clear matches in web search and their normalized names have a low fuzzy score (36.36%), indicating a lack of similarity.', 'evidence_urls': []}}
# Line 55: {'original_a': 'First National Bank;RBC Capital Markets', 'original_b': 'RBC CAPITAL MARKETS LLC', 'norm_a': 'first national bank rbc capital markets', 'norm_b': 'rbc capital markets', 'scores': {'ratio': 65.51724137931035, 'token_sort': 65.51724137931035, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:12:40.419144Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 56: {'original_a': 'Ross Sinclaire & Associates', 'original_b': 'ROSS SINCLAIRE AND ASSOCIATES INC', 'norm_a': 'ross sinclaire and associates', 'norm_b': 'ross sinclaire and associates', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:12:41.426494Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 57: {'original_a': 'Municipal Solutions Assoc', 'original_b': 'MUNICIPAL SOLUTIONS INC', 'norm_a': 'municipal solutions assoc', 'norm_b': 'municipal solutions', 'scores': {'ratio': 86.36363636363636, 'token_sort': 86.36363636363636, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:12:42.433753Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 58: {'original_a': 'Govt Development Bank for PR', 'original_b': 'GOVERNMENT DEVELOPMENT BANK OF PUERTO RICO', 'norm_a': 'govt development bank for pr', 'norm_b': 'government development bank of puerto rico', 'scores': {'ratio': 74.28571428571429, 'token_sort': 68.57142857142857, 'token_set': 72.72727272727272, 'partial': 82.14285714285714}, 'timestamp': '2025-09-27T05:12:43.441185Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 50,\n      "explanation": "Both names have high fuzzy scores but lack supporting evidence from web searches.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': 'Both names have high fuzzy scores but lack supporting evidence from web searches.', 'evidence_urls': []}}
# Line 59: {'original_a': 'Kaufman Hall & Associates Inc', 'original_b': 'KAUFMAN HALL AND ASSOCIATES INC', 'norm_a': 'kaufman hall and associates', 'norm_b': 'kaufman hall and associates', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:12:50.088579Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 60: {'original_a': 'Mountainside Capital Advisors', 'original_b': 'MOUNTAINSIDE CAPITAL ADVISORS LLC', 'norm_a': 'mountainside capital advisors', 'norm_b': 'mountainside capital advisors', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:12:51.096427Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 61: {'original_a': 'Cender & Company LLC', 'original_b': 'CENDER AND CO LLC', 'norm_a': 'cender and', 'norm_b': 'cender and', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:12:52.103115Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 62: {'original_a': 'Robert W Baird & Co Inc', 'original_b': 'ROBERT W BAIRD CO', 'norm_a': 'robert w baird and', 'norm_b': 'robert w baird', 'scores': {'ratio': 87.5, 'token_sort': 87.5, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:12:53.110369Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 63: {'original_a': 'Ruan Securities Inc', 'original_b': 'RUAN SECURITIES', 'norm_a': 'ruan securities', 'norm_b': 'ruan securities', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:12:54.117878Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 64: {'original_a': 'Public Financial Mgmt Inc', 'original_b': 'BANK OF NEW YORK MELLON TRUST CO NA', 'norm_a': 'public financial mgmt', 'norm_b': 'bank of new york mellon trust co na', 'scores': {'ratio': 25.0, 'token_sort': 25.0, 'token_set': 25.0, 'partial': 33.333333333333336}, 'timestamp': '2025-09-27T05:12:55.124670Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 30,\n      "explanation": "Both firms have low fuzzy scores and no meaningful web search results, making it difficult to determine with confidence whether they refer to the same legal entity.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 30, 'explanation': 'Both firms have low fuzzy scores and no meaningful web search results, making it difficult to determine with confidence whether they refer to the same legal entity.', 'evidence_urls': []}}
# Line 65: {'original_a': 'Fieldman Rolapp & Associates', 'original_b': 'FIELDMAN ROLAPP AND ASSOCIATES', 'norm_a': 'fieldman rolapp and associates', 'norm_b': 'fieldman rolapp and associates', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:13:02.100371Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 66: {'original_a': 'UniBank Fiscal Advisory Svcs', 'original_b': 'UNIBANK FISCAL ADVISORY SERVICES INC', 'norm_a': 'unibank fiscal advisory svcs', 'norm_b': 'unibank fiscal advisory services', 'scores': {'ratio': 93.33333333333333, 'token_sort': 93.33333333333333, 'token_set': 93.33333333333333, 'partial': 94.33962264150944}, 'timestamp': '2025-09-27T05:13:03.107779Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 50,\n      "explanation": "No useful hits found from web searches for either Original A or Original B, and high fuzzy score does not guarantee the same legal entity.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': 'No useful hits found from web searches for either Original A or Original B, and high fuzzy score does not guarantee the same legal entity.', 'evidence_urls': []}}
# Line 67: {'original_a': 'Caine Mitter & Associates Inc', 'original_b': 'CAINE MITTER AND ASSOCIATES INC', 'norm_a': 'caine mitter and associates', 'norm_b': 'caine mitter and associates', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:13:11.769304Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 68: {'original_a': 'BOSC Inc', 'original_b': 'OPPENHEIM', 'norm_a': 'bosc', 'norm_b': 'oppenheim', 'scores': {'ratio': 15.384615384615385, 'token_sort': 15.384615384615385, 'token_set': 15.384615384615387, 'partial': 40.0}, 'timestamp': '2025-09-27T05:13:12.776601Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 0,\n      "explanation": "Insufficient information and low fuzzy score indicate it\'s highly likely that \'BOSC Inc\' and \'Oppenheim\' do not refer to the same legal entity.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 0, 'explanation': "Insufficient information and low fuzzy score indicate it's highly likely that 'BOSC Inc' and 'Oppenheim' do not refer to the same legal entity.", 'evidence_urls': []}}
# Line 69: {'original_a': 'Municipal Resource Advisors', 'original_b': 'MUNICIPAL RESOURCE ADVISORS LLC', 'norm_a': 'municipal resource advisors', 'norm_b': 'municipal resource advisors', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:13:21.350239Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 70: {'original_a': 'Public Financial Mgmt Inc;ButcherMark Financial Advisors', 'original_b': 'PUBLIC FINANCIAL MANAGEMENT', 'norm_a': 'public financial mgmt inc butchermark financial advisors', 'norm_b': 'public financial management', 'scores': {'ratio': 53.012048192771076, 'token_sort': 55.42168674698795, 'token_set': 74.4186046511628, 'partial': 87.5}, 'timestamp': '2025-09-27T05:13:22.357427Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 50,\n      "explanation": "No clear match found based on provided information and web searches.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': 'No clear match found based on provided information and web searches.', 'evidence_urls': []}}
# Line 71: {'original_a': 'Stephen H McDonald & Assoc', 'original_b': 'STEPHEN H MCDONALD AND ASSOCIATES INC', 'norm_a': 'stephen h mcdonald and assoc', 'norm_b': 'stephen h mcdonald and associates', 'scores': {'ratio': 91.80327868852459, 'token_sort': 91.80327868852459, 'token_set': 91.80327868852459, 'partial': 100.0}, 'timestamp': '2025-09-27T05:13:30.123875Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 0,\n      "explanation": "Insufficient information and no useful web hits for either firm.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 0, 'explanation': 'Insufficient information and no useful web hits for either firm.', 'evidence_urls': []}}
# Line 72: {'original_a': 'Public Resource Advisory Group;Public Financial Mgmt Inc', 'original_b': 'PUBLIC FINANCIAL MANAGEMENT', 'norm_a': 'public resource advisory group public financial mgmt', 'norm_b': 'public financial management', 'scores': {'ratio': 53.16455696202531, 'token_sort': 53.16455696202531, 'token_set': 74.4186046511628, 'partial': 87.5}, 'timestamp': '2025-09-27T05:13:37.631160Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 50,\n      "explanation": "Both names are variations of \'Public Financial Management\', but lack sufficient context or supporting evidence from web search results to definitively confirm they refer to the same legal entity.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': "Both names are variations of 'Public Financial Management', but lack sufficient context or supporting evidence from web search results to definitively confirm they refer to the same legal entity.", 'evidence_urls': []}}
# Line 73: {'original_a': 'First National Bank', 'original_b': 'FIRST NATIONAL BANK OF HAMILTON', 'norm_a': 'first national bank', 'norm_b': 'first national bank of hamilton', 'scores': {'ratio': 76.0, 'token_sort': 76.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:13:44.870992Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 74: {'original_a': 'Ehlers & Associates', 'original_b': 'EHLERS AND ASSOCIATES INC', 'norm_a': 'ehlers and associates', 'norm_b': 'ehlers and associates', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:13:45.875608Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 75: {'original_a': 'Stan Bernstein & Associates', 'original_b': 'STAN BERNSTEIN AND ASSOCIATES INC', 'norm_a': 'stan bernstein and associates', 'norm_b': 'stan bernstein and associates', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:13:46.883048Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 76: {'original_a': 'Ehlers & Associates', 'original_b': 'EHLERS AND ASSOCIATES INC', 'norm_a': 'ehlers and associates', 'norm_b': 'ehlers and associates', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:13:47.887468Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 77: {'original_a': 'Davenport & Company LLC', 'original_b': 'DAVENPORT AND CO LLC', 'norm_a': 'davenport and', 'norm_b': 'davenport and', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:13:48.892173Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 78: {'original_a': 'Ring McAfee & Co', 'original_b': 'RING MCAFEE AND CO INC', 'norm_a': 'ring mcafee and', 'norm_b': 'ring mcafee and', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:13:49.899578Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 79: {'original_a': 'RBC Capital Markets', 'original_b': 'RBC CAPITAL MARKETS LLC', 'norm_a': 'rbc capital markets', 'norm_b': 'rbc capital markets', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:13:50.905241Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 80: {'original_a': 'New York Municipal Advisors', 'original_b': 'NEW YORK MUNICIPAL ADVISORS CORP', 'norm_a': 'new york municipal advisors', 'norm_b': 'new york municipal advisors', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:13:51.912750Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 81: {'original_a': 'JJB Hilliard WL Lyons Inc', 'original_b': 'JJB HILLIARD WL LYONS LLC', 'norm_a': 'jjb hilliard wl lyons', 'norm_b': 'jjb hilliard wl lyons', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:13:52.920062Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 82: {'original_a': 'Columbia Capital Management;CSG Advisors Incorporated', 'original_b': 'COLUMBIA CAPITAL MANAGEMENT LLC', 'norm_a': 'columbia capital management csg advisors', 'norm_b': 'columbia capital management', 'scores': {'ratio': 80.59701492537313, 'token_sort': 80.59701492537313, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:13:53.927345Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 83: {'original_a': 'Public Financial Mgmt Inc;Leora Consulting Group LLC', 'original_b': 'PUBLIC FINANCIAL MANAGEMENT', 'norm_a': 'public financial mgmt inc leora consulting group', 'norm_b': 'public financial management', 'scores': {'ratio': 61.33333333333333, 'token_sort': 58.666666666666664, 'token_set': 74.4186046511628, 'partial': 87.5}, 'timestamp': '2025-09-27T05:13:54.934257Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 50,\n      "explanation": "Both firms have similar names but different casing and lack significant online presence for definitive matching.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': 'Both firms have similar names but different casing and lack significant online presence for definitive matching.', 'evidence_urls': []}}
# Line 84: {'original_a': 'TLHocking & Associates', 'original_b': 'TL HOCKING AND ASSOCIATES LLC', 'norm_a': 'tlhocking and associates', 'norm_b': 'tl hocking and associates', 'scores': {'ratio': 97.95918367346938, 'token_sort': 89.79591836734694, 'token_set': 89.79591836734694, 'partial': 95.83333333333334}, 'timestamp': '2025-09-27T05:14:01.498939Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "possible_match",\n      "confidence": 97.95,\n      "explanation": "Both names have a high fuzzy score and share similar spelling patterns, suggesting they might refer to the same entity.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'possible_match', 'confidence': 97.95, 'explanation': 'Both names have a high fuzzy score and share similar spelling patterns, suggesting they might refer to the same entity.', 'evidence_urls': []}}
# Line 85: {'original_a': 'Southwest Securities', 'original_b': 'SOUTHWEST SECURITIES INC', 'norm_a': 'southwest securities', 'norm_b': 'southwest securities', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:14:09.980123Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 86: {'original_a': 'Ehlers & Associates', 'original_b': 'EHLERS AND ASSOCIATES INC', 'norm_a': 'ehlers and associates', 'norm_b': 'ehlers and associates', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:14:10.982476Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 87: {'original_a': 'Umbaugh LLP', 'original_b': 'H J UMBAUGH AND ASSOCIATES', 'norm_a': 'umbaugh', 'norm_b': 'h j umbaugh and associates', 'scores': {'ratio': 42.42424242424242, 'token_sort': 42.42424242424242, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:14:11.990091Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 88: {'original_a': 'Rathmann & Associates', 'original_b': 'RATHMANN AND ASSOCIATES LP', 'norm_a': 'rathmann and associates', 'norm_b': 'rathmann and associates lp', 'scores': {'ratio': 93.87755102040816, 'token_sort': 93.87755102040816, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:14:12.997539Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 89: {'original_a': 'Dunlap & Associates', 'original_b': 'DUNLAP AND ASSOCIATES INC', 'norm_a': 'dunlap and associates', 'norm_b': 'dunlap and associates', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:14:14.004895Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 90: {'original_a': 'A Dashen & Associates', 'original_b': 'A DASHEN AND ASSOCIATES', 'norm_a': 'a dashen and associates', 'norm_b': 'a dashen and associates', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:14:15.008582Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 91: {'original_a': 'David Drown Associates', 'original_b': 'DAVID DROWN ASSOCIATES INC', 'norm_a': 'david drown associates', 'norm_b': 'david drown associates', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:14:16.014528Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 92: {'original_a': 'Southwest Securities Inc', 'original_b': 'SOUTHWEST SECURITIES', 'norm_a': 'southwest securities', 'norm_b': 'southwest securities', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:14:17.021255Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 93: {'original_a': 'Jefferies & Company Inc', 'original_b': 'JEFFERIES AND CO INC', 'norm_a': 'jefferies and', 'norm_b': 'jefferies and', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:14:18.027845Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 94: {'original_a': 'Rathmann & Associates', 'original_b': 'RATHMANN AND ASSOCIATES LP', 'norm_a': 'rathmann and associates', 'norm_b': 'rathmann and associates lp', 'scores': {'ratio': 93.87755102040816, 'token_sort': 93.87755102040816, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:14:19.034627Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 95: {'original_a': 'Capital Financial Advisors', 'original_b': 'CAPITAL FINANCIAL ADVISORS INC', 'norm_a': 'capital financial advisors', 'norm_b': 'capital financial advisors', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:14:20.041482Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 96: {'original_a': 'George K Baum & Company Inc', 'original_b': 'GEORGE K BAUM AND CO', 'norm_a': 'george k baum and', 'norm_b': 'george k baum and', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:14:21.048171Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 97: {'original_a': 'Public Resource Advisory Group;Public Financial Mgmt Inc', 'original_b': 'PUBLIC RESOURCES ADVISORY GRP', 'norm_a': 'public resource advisory group public financial mgmt', 'norm_b': 'public resources advisory grp', 'scores': {'ratio': 69.1358024691358, 'token_sort': 69.1358024691358, 'token_set': 75.67567567567568, 'partial': 96.42857142857143}, 'timestamp': '2025-09-27T05:14:22.051600Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 50,\n      "explanation": "Both firm names have similar structures and contain \'public resources advisory\'. However, the absence of useful web hits for both entities makes it difficult to confirm they refer to the same legal entity.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': "Both firm names have similar structures and contain 'public resources advisory'. However, the absence of useful web hits for both entities makes it difficult to confirm they refer to the same legal entity.", 'evidence_urls': []}}
# Line 98: {'original_a': 'Southwest Securities', 'original_b': 'SOUTHWEST SECURITIES INC', 'norm_a': 'southwest securities', 'norm_b': 'southwest securities', 'scores': {'ratio': 100.0, 'token_sort': 100.0, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:14:29.503961Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 99: {'original_a': 'Webster Bank', 'original_b': 'WEBSTER BANK NA', 'norm_a': 'webster bank', 'norm_b': 'webster bank na', 'scores': {'ratio': 88.88888888888889, 'token_sort': 88.88888888888889, 'token_set': 100.0, 'partial': 100.0}, 'timestamp': '2025-09-27T05:14:30.507273Z', 'llm_verdict': 'same', 'llm_confidence': 98, 'llm_explanation': 'very high token_set fuzzy match', 'evidence_urls': []}
# Line 100: {'original_a': 'Public Financial Mgmt Inc', 'original_b': 'PUBLIC FINANCE MANAGEMENT INC', 'norm_a': 'public financial mgmt', 'norm_b': 'public finance management', 'scores': {'ratio': 78.26086956521739, 'token_sort': 78.26086956521739, 'token_set': 78.26086956521739, 'partial': 81.08108108108108}, 'timestamp': '2025-09-27T05:14:31.509893Z', 'ddg_a': [], 'ddg_b': [], 'llm_raw': ' {\n      "verdict": "ambiguous",\n      "confidence": 50,\n      "explanation": "Both firm names have slight differences in capitalization and spacing, and there were no useful web hits to verify their identity.",\n      "evidence_urls": []\n   }', 'llm_parsed': {'verdict': 'ambiguous', 'confidence': 50, 'explanation': 'Both firm names have slight differences in capitalization and spacing, and there were no useful web hits to verify their identity.', 'evidence_urls': []}}
# Stopped due to max lines = 100
